# %%
import networkx as nx
import numpy as np
import torch
from datetime import datetime
import os
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
import torch_geometric.nn as geom_nn

from geneticalgorithm import geneticalgorithm as ga
import sys


import pandas as pd
import torch_geometric.transforms as T

sys.path.append("Models/")
from models import GNN

sys.path.append("FastCover/")

from utils import *

# %%
print(f"\nMDH value: {Func(_, MDH = True)}\n")

for i in range(1):
    
    print(f"\n -- Next layer {layers[i]} -- \n")

    varbound = np.array([[-10,10]] * getDimParams(Models[i]) )

    algorithm_param = {'max_num_iteration' : max_iterations,\
                       'population_size' : pop_size,\
                       'mutation_probability' : 0.4,\
                       'elit_ratio': elitratio,\
                       'crossover_probability': 0.5,\
                       'parents_portion': 0.3,\
                       'crossover_type' : 'uniform',\
                       'max_iteration_without_improv' : max_iterations//2}

    GA_model = ga(function = Func,\
                dimension = getDimParams(Models[i]),\
                variable_type = 'real',\
                variable_boundaries = varbound,\
                algorithm_parameters = algorithm_param,
                function_timeout = 1_000_000,
                convergence_curve = False)

    GA_model.run()
    
    sd = getStateDict(Models[i], GA_model.best_variable)
    Models[i].load_state_dict(sd)
    
    
    torch.save(Models[i].state_dict(), 
                       f=f"{PATH_SAVE_TRAINS}{layers[i]}_seed_{SEED}_thr_{int(threshold*10)}_date_{dt_string}.pt")
# Out:
# MDH value: 0.10980000000000001
#
#
#  -- Next layer GCN --
#
#  The best solution found:
#  [ 6.8700422  -9.985355    7.05937959 -8.15461599  5.10598043 -5.70885444
#   6.3957135  -5.6072306   3.24511135  0.87082769  0.66981579 -9.66719836]
#
#  Objective function:
#  0.1448
#
#  -- Next layer GAT --
#
#  The best solution found:
#  [ 8.3139919  -3.75410222 -4.06345056 -7.89338595 -4.67451582 -9.66935643
#  -4.53386547  5.61591643  4.05084383 -6.74853872 -7.15781156  7.00374903
#  -6.3260968  -6.4833673   6.57493511 -9.7774226   7.12981889 -5.39548039
#  -8.92924538 -7.83215412  6.71131878  8.3187963   1.89962889 -5.52080425
#   1.30966107 -9.26320274  0.90513122  2.19709128  8.17347306  1.50900392
#  -6.63167342 -0.61815319  0.99262082  9.52104568  0.02769271  1.83246848
#   7.59793191  3.41168482  3.14364795  8.06065282  6.00915683  7.59111487
#  -1.45708027  8.77571429 -5.74719544 -4.15588687  4.81835657  2.91249344
#   5.35811241  7.16622539 -9.56471958  6.67210614  6.9359861   4.82100535
#  -5.9733312   2.88500321 -5.58006918 -3.52273701  0.37344395 -5.30199441
#  -2.41574713  6.04437041 -8.12312313  4.18062173  5.50942253  5.03611987
#  -9.8275258   5.48823367  2.04427004 -9.23738341 -5.716357   -2.0716161
#   1.42880069  0.5505264   0.36872955 -3.41895823  8.91531887 -7.59171721
#   6.13074037  1.78715274  2.08903582  9.32554202 -5.93462121  9.27596523
#   1.85853229 -4.20955059  0.9654439  -1.10380308  3.48501528 -5.59266182
#  -4.8953103   4.79231809  5.97312712 -0.05011015 -1.7646663   0.9035706
#   9.86227099 -0.75581337  1.6938242  -8.25234973  6.31961429 -2.55414642
#   6.28598301 -7.25184376  4.0028848   3.53535019  8.76515034 -1.2427774
#   1.39185112  0.44908105  9.0609065  -0.39844648 -8.01083069 -5.8930931
#  -3.7409138  -6.32449339 -8.657445   -6.75740973  3.20319389 -0.70217459
#   9.25407641 -8.16730732 -4.45807808  8.13330599  4.72751251 -5.4116408
#  -1.40702293 -4.53530742 -7.19722312  7.48579173 -0.90423399  5.26196904
#  -5.94382428 -1.51818302  0.73825139 -1.25310796 -7.13984738  7.62553816
#  -0.88120745  5.64672343 -5.76238294  2.37355408 -0.10119551  2.48663487
#   4.08565466  1.82208474 -4.80191202  0.64176867 -8.31307608 -1.49596067
#  -3.23920874 -9.37553729  4.95559911 -1.20857494]
#
#  Objective function:
#  0.20675000000000004

# %% [markdown]
# ## Revisando las features

# %%
PATH_TO_TRAIN = "./BRKGA/instances/scalefree/train/"

PATH_SAVE_TRAINS = "Models/runs/scalefree/GA/"
SEED = 13

max_iterations = 1
pop_size = 2
elitratio = 0.1
threshold = 0.5

dt_string = datetime.now().strftime("%m-%d_%H-%M")

# %%
def loadFeatures(file, remove_degree = True, remove_BC = False):
#file = "./BRKGA/instances/socialnetworks/feats/graph_karate_feat.txt"
    temp = []
    with open(file) as f:
        c = 0
        for line in f.readlines()[1:]:
            c+=1
            feats = np.array(line.split(","), dtype = float)
            temp.append(feats)
        temp = np.array(temp)
    FeaturesDF = pd.DataFrame(temp)
    FeaturesDF.columns = ["BC", "PageRank", "degree", "closeness_centrality", "EigenDegree"]
    if remove_degree:
        FeaturesDF = FeaturesDF.drop(["degree"], axis = 1)
    if remove_BC:
        FeaturesDF = FeaturesDF.drop(["BC"], axis = 1)
    return FeaturesDF

def loadGraph(file):
    return igraph.Graph.Read_Edgelist(file, directed = False).to_networkx()
    

def plotFeatures(file, plot_ = True):
    #file = "./BRKGA/instances/socialnetworks/feats/deezer_HR_feat.txt"
    DataFeats = loadFeatures(file, remove_degree = True)
    print(DataFeats.shape)
    print(DataFeats.describe())
    
    if plot_:
        DataFeats.boxplot();
        name = file.split("/")[-1]
        plt.title(f"Feature boxplot for {name} size: {DataFeats.shape[0]}")
        plt.show()

# %%
def checkFeaturesTargetSet(G, DataFeats):
    Targets = []
    for col in DataFeats.columns:
        _, ts = FindMinimumTarget(G, out = torch.tensor(DataFeats[col]), threshold = 0.5)
        Targets.append(ts)
        print(f"for {col} TargetSet: {ts}")
    _, ts = FindMinimumTarget(G, out = None, threshold = 0.5)
    print(f"for MDH TargetSet: {ts}")
    Targets.append(ts)
    return Targets

# %%
def CheckAll(file, file_graph):
    #file = "./BRKGA/instances/socialnetworks/feats/graph_karate_feat.txt"
    #file_graph = "./BRKGA/instances/socialnetworks/txt/graph_karate.txt"
    DataFeats = loadFeatures(file)
    plotFeatures(file, plot_ = False)

    G = loadGraph(file_graph)
    print()
    vals = checkFeaturesTargetSet(G, DataFeats)
    vals.append(DataFeats.shape[0])
    return vals

# %%
def Scale(X):
    return (X - np.min(X)) / (np.max(X) - np.min(X))

def Standar(X):
    return (X - np.mean(X)) / np.std(X)

# %%
graphFeatures = [PATH_TO_TRAIN+"feats/"+feat for feat in os.listdir(PATH_TO_TRAIN+'feats')]
graphs = [PATH_TO_TRAIN+"txt/"+feat for feat in os.listdir(PATH_TO_TRAIN+'txt')]

# %%
file = "./BRKGA/instances/socialnetworks/feats/graph_karate_feat.txt"
file_graph = "./BRKGA/instances/socialnetworks/txt/graph_karate.txt"
CheckAll(file, file_graph)
# Out:
# (62, 4)
#               BC   PageRank  closeness_centrality  EigenDegree
# count  62.000000  62.000000             62.000000    62.000000
# mean    0.039283   0.016129              0.307240     0.090777
# std     0.050965   0.007833              0.052027     0.089542
# min     0.000000   0.004835              0.178363     0.000537
# 25%     0.003083   0.009686              0.261567     0.018322
# 50%     0.021630   0.015781              0.316062     0.047450
# 75%     0.056086   0.021398              0.338889     0.158907
# max     0.248237   0.032137              0.417808     0.315781
#
# for BC TargetSet: 12
# for PageRank TargetSet: 8
# for closeness_centrality TargetSet: 13
# for EigenDegree TargetSet: 10
# for MDH TargetSet: 8
# [12, 8, 13, 10, 8, 62]

# %%
i = 10
CheckAll(graphFeatures[i], graphs[i])
# Out:
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.000992     0.001000              0.503241     0.028524
# std       0.001138     0.000407              0.016642     0.013658
# min       0.000057     0.000436              0.444989     0.009142
# 25%       0.000340     0.000721              0.491392     0.019177
# 50%       0.000567     0.000868              0.502262     0.024140
# 75%       0.001125     0.001151              0.514418     0.033415
# max       0.008403     0.002815              0.551934     0.090605
#
# for BC TargetSet: 197
# for PageRank TargetSet: 200
# for closeness_centrality TargetSet: 198
# for EigenDegree TargetSet: 201
# for MDH TargetSet: 198
# [197, 200, 198, 201, 198, 1000]

# %% [markdown]
# ## Para socialnetworks

# %%
Trials = ["graph_karate", "socfb-Mich67", "graph_ncstrlwg2", "graph_CA-HepPh", "graph_CA-AstroPh", 
          "musae_git", "graph_CA-CondMat", "graph_Email-Enron", "gemsec_facebook_artist", "deezer_HR"]
Res = {t:[] for t in Trials}
for trial in Trials:
    print(f"\n------ {trial} ------\n")
    file = "./BRKGA/instances/socialnetworks/feats/"+trial+"_feat.txt"
    file_graph = "./BRKGA/instances/socialnetworks/txt/"+trial+".txt"
    Res[trial] = CheckAll(file, file_graph)
# Out:
# ------ graph_karate ------
#
# (62, 4)
#               BC   PageRank  closeness_centrality  EigenDegree
# count  62.000000  62.000000             62.000000    62.000000
# mean    0.039283   0.016129              0.307240     0.090777
# std     0.050965   0.007833              0.052027     0.089542
# min     0.000000   0.004835              0.178363     0.000537
# 25%     0.003083   0.009686              0.261567     0.018322
# 50%     0.021630   0.015781              0.316062     0.047450
# 75%     0.056086   0.021398              0.338889     0.158907
# max     0.248237   0.032137              0.417808     0.315781
#
# for BC TargetSet: 12
# for PageRank TargetSet: 8
# for closeness_centrality TargetSet: 13
# for EigenDegree TargetSet: 10
# for MDH TargetSet: 8
#
# ------ socfb-Mich67 ------
#
# (3748, 4)
#                 BC     PageRank  closeness_centrality   EigenDegree
# count  3748.000000  3748.000000           3748.000000  3.748000e+03
# mean      0.000493     0.000267              0.356777  9.193655e-03
# std       0.001047     0.000207              0.042598  1.350312e-02
# min       0.000000     0.000044              0.000356  1.563267e-28
# 25%       0.000029     0.000122              0.331539  1.148615e-03
# 50%       0.000148     0.000211              0.359159  3.964724e-03
# 75%       0.000502     0.000349              0.385402  1.098744e-02
# max       0.023123     0.002096              0.480849  1.107463e-01
#
# for BC TargetSet: 418
# for PageRank TargetSet: 250
# for closeness_centrality TargetSet: 246
# for EigenDegree TargetSet: 204
# for MDH TargetSet: 206
#
# ------ graph_ncstrlwg2 ------
#
# (6396, 4)
#                 BC     PageRank  closeness_centrality   EigenDegree
# count  6396.000000  6396.000000           6396.000000  6.396000e+03
# mean      0.001485     0.000156              0.098331  8.685707e-04
# std       0.005470     0.000113              0.016330  1.247468e-02
# min       0.000000     0.000032              0.044945  2.361646e-25
# 25%       0.000000     0.000092              0.086804  2.613782e-12
# 50%       0.000000     0.000127              0.098773  2.164454e-10
# 75%       0.000156     0.000181              0.110280  8.975400e-09
# max       0.090688     0.001718              0.149047  2.165883e-01
#
# for BC TargetSet: 1266
# for PageRank TargetSet: 1103
# for closeness_centrality TargetSet: 1308
# for EigenDegree TargetSet: 1314
# for MDH TargetSet: 1108
#
# ------ graph_CA-HepPh ------
#
# (12008, 4)
#                  BC      PageRank  closeness_centrality   EigenDegree
# count  12008.000000  12008.000000          12008.000000  1.200800e+04
# mean       0.000263      0.000083              0.191061  1.672713e-03
# std        0.000918      0.000076              0.059802  8.971430e-03
# min        0.000000      0.000000              0.000000  0.000000e+00
# 25%        0.000000      0.000036              0.177073  2.434022e-08
# 50%        0.000000      0.000063              0.199845  1.489365e-06
# 75%        0.000094      0.000096              0.222962  4.642415e-05
# max        0.029274      0.000817              0.306442  7.016681e-02
# FastCover\utils.py:111: RuntimeWarning: invalid value encountered in true_divide
#   Infected += (Num_Neighs_Infected/Num_Neighs >= threshold)
# for BC TargetSet: 1749
# for PageRank TargetSet: 1519
# for closeness_centrality TargetSet: 1696
# for EigenDegree TargetSet: 1821
# for MDH TargetSet: 1525
#
# ------ graph_CA-AstroPh ------
#
# (18772, 4)
#                  BC      PageRank  closeness_centrality   EigenDegree
# count  1.877200e+04  18772.000000          18772.000000  18772.000000
# mean   1.551386e-04      0.000053              0.221691      0.002289
# std    5.645236e-04      0.000048              0.058353      0.006931
# min    0.000000e+00      0.000000              0.000000      0.000000
# 25%    0.000000e+00      0.000023              0.206888      0.000019
# 50%    8.599218e-07      0.000040              0.231757      0.000217
# 75%    7.232553e-05      0.000063              0.253385      0.001388
# max    2.847202e-02      0.000715              0.333642      0.145652
# FastCover\utils.py:111: RuntimeWarning: invalid value encountered in true_divide
#   Infected += (Num_Neighs_Infected/Num_Neighs >= threshold)
# for BC TargetSet: 1963
# for PageRank TargetSet: 1722
# for closeness_centrality TargetSet: 1763
# for EigenDegree TargetSet: 1895
# for MDH TargetSet: 1637
#
# ------ musae_git ------
#
# (37700, 4)
#                  BC      PageRank  closeness_centrality   EigenDegree
# count  3.770000e+04  37700.000000          37700.000000  3.770000e+04
# mean   6.021929e-05      0.000027              0.313667  2.372857e-03
# std    1.939652e-03      0.000130              0.040806  4.571138e-03
# min    0.000000e+00      0.000005              0.141389  3.543992e-12
# 25%    1.707436e-08      0.000008              0.284141  1.671725e-04
# 50%    9.572588e-07      0.000013              0.311260  1.083886e-03
# 75%    1.173095e-05      0.000024              0.346949  3.186910e-03
# max    2.698645e-01      0.016514              0.523081  3.559490e-01
#
# for BC TargetSet: 453
# for PageRank TargetSet: 225
# for closeness_centrality TargetSet: 513
# for EigenDegree TargetSet: 211
# for MDH TargetSet: 196
#
# ------ graph_CA-CondMat ------
#
# (23133, 4)
#                  BC      PageRank  closeness_centrality   EigenDegree
# count  23133.000000  23133.000000          23133.000000  2.313300e+04
# mean       0.000162      0.000043              0.162254  1.491787e-03
# std        0.000809      0.000037              0.051629  6.403486e-03
# min        0.000000      0.000009              0.000043  8.990078e-36
# 25%        0.000000      0.000023              0.155652  5.546269e-06
# 50%        0.000000      0.000034              0.173920  7.068503e-05
# 75%        0.000054      0.000048              0.189667  5.833593e-04
# max        0.072086      0.001087              0.275673  2.270058e-01
#
# for BC TargetSet: 3189
# for PageRank TargetSet: 2884
# for closeness_centrality TargetSet: 3460
# for EigenDegree TargetSet: 3610
# for MDH TargetSet: 2936
#
# ------ graph_Email-Enron ------
#
# (36692, 4)
#                  BC      PageRank  closeness_centrality   EigenDegree
# count  3.669200e+04  36692.000000          36692.000000  3.669200e+04
# mean   7.014477e-05      0.000027              0.213176  1.447471e-03
# std    9.269667e-04      0.000097              0.069448  5.015916e-03
# min    0.000000e+00      0.000005              0.000027  5.476616e-22
# 25%    0.000000e+00      0.000009              0.207117  2.217717e-05
# 50%    0.000000e+00      0.000015              0.231984  2.542151e-04
# 75%    5.485888e-07      0.000025              0.248828  9.466501e-04
# max    6.243635e-02      0.011403              0.355739  1.495614e-01
#
# for BC TargetSet: 3107
# for PageRank TargetSet: 2901
# for closeness_centrality TargetSet: 3034
# for EigenDegree TargetSet: 3033
# for MDH TargetSet: 2880
#
# ------ gemsec_facebook_artist ------
#
# (50515, 4)
#                  BC      PageRank  closeness_centrality   EigenDegree
# count  5.051500e+04  50515.000000          50515.000000  5.051500e+04
# mean   5.242367e-05      0.000020              0.274973  1.520153e-03
# std    3.813120e-04      0.000030              0.031170  4.181576e-03
# min    0.000000e+00      0.000003              0.130864  1.898858e-13
# 25%    1.525684e-07      0.000007              0.254635  4.968112e-05
# 50%    2.463199e-06      0.000012              0.275743  2.544120e-04
# 75%    1.883636e-05      0.000022              0.296242  1.041889e-03
# max    2.613579e-02      0.000840              0.398765  8.701860e-02
#
# for BC TargetSet: 1134
# for PageRank TargetSet: 869
# for closeness_centrality TargetSet: 1127
# for EigenDegree TargetSet: 834
# for MDH TargetSet: 789
#
# ------ deezer_HR ------
#
# (54573, 4)
#                  BC      PageRank  closeness_centrality   EigenDegree
# count  54573.000000  54573.000000          54573.000000  5.457300e+04
# mean       0.000064      0.000018              0.224159  1.881092e-03
# std        0.000258      0.000012              0.021981  3.845236e-03
# min        0.000000      0.000003              0.120450  3.755857e-11
# 25%        0.000003      0.000010              0.209805  8.224313e-05
# 50%        0.000015      0.000016              0.225080  4.087885e-04
# 75%        0.000051      0.000024              0.239604  1.912531e-03
# max        0.030419      0.000315              0.326516  1.054254e-01
#
# for BC TargetSet: 4814
# for PageRank TargetSet: 3271
# for closeness_centrality TargetSet: 3763
# for EigenDegree TargetSet: 2883
# for MDH TargetSet: 2377

# %%
ResSN = pd.DataFrame(Res).T
ResSN.columns = ["BC", "PageRank","closeness_centrality","EigenDegree","MDH" ,"size"]
ResSN
# Out:
#                           BC  PageRank  closeness_centrality  EigenDegree  \
# graph_karate              12         8                    13           10
# socfb-Mich67             418       250                   246          204
# graph_ncstrlwg2         1266      1103                  1308         1314
# graph_CA-HepPh          1749      1519                  1696         1821
# graph_CA-AstroPh        1963      1722                  1763         1895
# musae_git                453       225                   513          211
# graph_CA-CondMat        3189      2884                  3460         3610
# graph_Email-Enron       3107      2901                  3034         3033
# gemsec_facebook_artist  1134       869                  1127          834
# deezer_HR               4814      3271                  3763         2883
#
#                          MDH   size
# graph_karate               8     62
# socfb-Mich67             206   3748
# graph_ncstrlwg2         1108   6396
# graph_CA-HepPh          1525  12008
# graph_CA-AstroPh        1637  18772
# musae_git                196  37700
# graph_CA-CondMat        2936  23133
# graph_Email-Enron       2880  36692
# gemsec_facebook_artist   789  50515
# deezer_HR               2377  54573

# %%
ResSN.to_csv("SN_Diffusion_results_for_features.csv")

# %%
i = 0
DataFeats = loadFeatures(graphFeatures[i], remove_degree = False)
for feat in DataFeats.columns:
    #fig, ax = plt.subplots(figsize=(3,2)) 
    (DataFeats[feat]).hist()
    name = graphFeatures[i].split("/")[-1].replace("graph1__", "").replace("_1000", "").replace("_feat.txt", "")
    fn = feat.replace("_centrality", "")
    if fn != "BC":
        fn = fn.capitalize()
    
    plt.title(f"{fn} distribution")
    print(name)
    plt.show()
# Out:
# 2.25_10
# 2.25_10
# 2.25_10
# 2.25_10
# 2.25_10

# %%
file = "./BRKGA/instances/socialnetworks/feats/deezer_HR_feat.txt"
DataFeats = loadFeatures(file, remove_degree = False)

for feat in DataFeats.columns:
    fig, ax = plt.subplots(figsize=(3,2)) 
    Standar(DataFeats[feat]).hist()
    name = file.split("/")[-1]
    plt.title(f"{feat} for {name}")
    plt.show()

# %%
np.sum(Standar(DataFeats.BC)>0.1)
# Out:
# 14525

# %%
file = "./BRKGA/instances/socialnetworks/feats/com-dblp.ungraph_feat.txt"
DataFeats = loadFeatures(file, remove_degree = True)

plotFeatures(file, plot_ = False)
# Out:
# (317080, 4)
#                   BC      PageRank  closeness_centrality   EigenDegree
# count  317080.000000  3.170800e+05         317080.000000  3.170800e+05
# mean        0.000018  3.153778e-06              0.149551  4.575209e-05
# std         0.000137  2.952273e-06              0.018079  1.775301e-03
# min         0.000000  5.142417e-07              0.065838  1.799850e-22
# 25%         0.000000  1.780517e-06              0.137910  1.717584e-10
# 50%         0.000000  2.420416e-06              0.150167  3.106903e-09
# 75%         0.000003  3.308642e-06              0.161779  6.305821e-08
# max         0.012514  9.764623e-05              0.222223  9.961821e-02

# %% [markdown]
# ## Ahora con Erdos

# %%
PATH_TO_TRAIN = "./BRKGA/instances/Erdos/test/"
graphs = [(feat).replace(".txt", "") for feat in os.listdir(PATH_TO_TRAIN+'txt')]
graphs = []
PATH_TO_TRAIN = "./BRKGA/instances/Erdos/train/"
graphs += [(feat).replace(".txt", "") for feat in os.listdir(PATH_TO_TRAIN+'txt')]
print(len(graphs))
#graphs = np.random.choice(graphs, 10)
graphs
# Out:
# 36
# ['ER_1000_10_0',
#  'ER_1000_10_1',
#  'ER_1000_10_2',
#  'ER_1000_10_3',
#  'ER_1000_15_0',
#  'ER_1000_15_1',
#  'ER_1000_15_2',
#  'ER_1000_15_3',
#  'ER_1000_20_0',
#  'ER_1000_20_1',
#  'ER_1000_20_2',
#  'ER_1000_20_3',
#  'ER_2000_10_0',
#  'ER_2000_10_1',
#  'ER_2000_10_2',
#  'ER_2000_10_3',
#  'ER_2000_15_0',
#  'ER_2000_15_1',
#  'ER_2000_15_2',
#  'ER_2000_15_3',
#  'ER_2000_20_0',
#  'ER_2000_20_1',
#  'ER_2000_20_2',
#  'ER_2000_20_3',
#  'ER_5000_10_0',
#  'ER_5000_10_1',
#  'ER_5000_10_2',
#  'ER_5000_10_3',
#  'ER_5000_15_0',
#  'ER_5000_15_1',
#  'ER_5000_15_2',
#  'ER_5000_15_3',
#  'ER_5000_20_0',
#  'ER_5000_20_1',
#  'ER_5000_20_2',
#  'ER_5000_20_3']

# %%
Trials = graphs.copy()

Res = {t:[] for t in Trials}
for trial in Trials:
    print(f"\n------ {trial} ------\n")
    file = "./BRKGA/instances/Erdos/train/feats/"+trial+"_feat.txt"
    file_graph = "./BRKGA/instances/Erdos/train/txt/"+trial+".txt"
    Res[trial] = CheckAll(file, file_graph)
# Out:
# ------ ER_1000_10_0 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.002251     0.001000              0.308173     0.029697
# std       0.001427     0.000271              0.015228     0.010872
# min       0.000023     0.000316              0.254782     0.005160
# 25%       0.001198     0.000819              0.298833     0.022215
# 50%       0.002012     0.000997              0.309671     0.029269
# 75%       0.003031     0.001167              0.318787     0.036712
# max       0.010424     0.002146              0.354004     0.087596
#
# for BC TargetSet: 165
# for PageRank TargetSet: 157
# for closeness_centrality TargetSet: 170
# for EigenDegree TargetSet: 181
# for MDH TargetSet: 162
#
# ------ ER_1000_10_1 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.002286     0.001000              0.305725     0.029672
# std       0.001488     0.000266              0.014619     0.010940
# min       0.000042     0.000331              0.247952     0.004546
# 25%       0.001215     0.000828              0.296000     0.021687
# 50%       0.002028     0.000994              0.306066     0.028323
# 75%       0.002948     0.001171              0.315964     0.036487
# max       0.009808     0.002088              0.344245     0.075252
#
# for BC TargetSet: 170
# for PageRank TargetSet: 162
# for closeness_centrality TargetSet: 177
# for EigenDegree TargetSet: 177
# for MDH TargetSet: 158
#
# ------ ER_1000_10_2 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.002230     0.001000              0.310392     0.029880
# std       0.001406     0.000254              0.014354     0.010358
# min       0.000126     0.000324              0.262895     0.006389
# 25%       0.001212     0.000817              0.301448     0.022671
# 50%       0.001893     0.000981              0.310731     0.028805
# 75%       0.003007     0.001155              0.320706     0.036380
# max       0.008820     0.001930              0.350649     0.073053
#
# for BC TargetSet: 176
# for PageRank TargetSet: 170
# for closeness_centrality TargetSet: 189
# for EigenDegree TargetSet: 186
# for MDH TargetSet: 177
#
# ------ ER_1000_10_3 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.002272     0.001000              0.307022     0.029715
# std       0.001447     0.000259              0.014761     0.010824
# min       0.000000     0.000248              0.230025     0.002223
# 25%       0.001239     0.000830              0.297476     0.021969
# 50%       0.002001     0.000995              0.307479     0.028821
# 75%       0.002945     0.001160              0.317244     0.036511
# max       0.012217     0.002270              0.352381     0.082269
#
# for BC TargetSet: 170
# for PageRank TargetSet: 163
# for closeness_centrality TargetSet: 182
# for EigenDegree TargetSet: 182
# for MDH TargetSet: 162
#
# ------ ER_1000_15_0 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001812     0.001000              0.356374     0.030505
# std       0.000958     0.000214              0.011011     0.008339
# min       0.000124     0.000429              0.314151     0.010077
# 25%       0.001098     0.000832              0.349790     0.024527
# 50%       0.001685     0.000990              0.357424     0.030025
# 75%       0.002346     0.001145              0.363802     0.035775
# max       0.007175     0.001874              0.385714     0.064632
#
# for BC TargetSet: 209
# for PageRank TargetSet: 199
# for closeness_centrality TargetSet: 213
# for EigenDegree TargetSet: 219
# for MDH TargetSet: 202
#
# ------ ER_1000_15_1 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001826     0.001000              0.354325     0.030521
# std       0.000963     0.000217              0.011367     0.008277
# min       0.000074     0.000327              0.292533     0.005995
# 25%       0.001110     0.000842              0.348175     0.025053
# 50%       0.001667     0.000992              0.355453     0.030196
# 75%       0.002345     0.001137              0.361825     0.035708
# max       0.006638     0.001736              0.383199     0.059866
#
# for BC TargetSet: 196
# for PageRank TargetSet: 190
# for closeness_centrality TargetSet: 220
# for EigenDegree TargetSet: 217
# for MDH TargetSet: 190
#
# ------ ER_1000_15_2 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001834     0.001000              0.353609     0.030433
# std       0.000985     0.000221              0.011554     0.008598
# min       0.000202     0.000434              0.305131     0.009601
# 25%       0.001082     0.000840              0.346634     0.024327
# 50%       0.001673     0.001002              0.354570     0.030020
# 75%       0.002346     0.001134              0.361564     0.035880
# max       0.006713     0.001828              0.383346     0.062728
#
# for BC TargetSet: 206
# for PageRank TargetSet: 194
# for closeness_centrality TargetSet: 204
# for EigenDegree TargetSet: 203
# for MDH TargetSet: 197
#
# ------ ER_1000_15_3 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001820     0.001000              0.354705     0.030498
# std       0.000907     0.000210              0.011197     0.008363
# min       0.000011     0.000323              0.291254     0.006453
# 25%       0.001151     0.000844              0.348084     0.024594
# 50%       0.001694     0.000997              0.355516     0.029776
# 75%       0.002386     0.001153              0.362877     0.036199
# max       0.005966     0.001751              0.382612     0.061401
#
# for BC TargetSet: 208
# for PageRank TargetSet: 202
# for closeness_centrality TargetSet: 217
# for EigenDegree TargetSet: 219
# for MDH TargetSet: 205
#
# ------ ER_1000_20_0 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001650     0.001000              0.377927     0.030757
# std       0.000763     0.000189              0.009866     0.007353
# min       0.000135     0.000502              0.343299     0.011545
# 25%       0.001054     0.000853              0.370824     0.025164
# 50%       0.001533     0.000978              0.377837     0.030214
# 75%       0.002132     0.001138              0.385008     0.036021
# max       0.005183     0.001595              0.404290     0.051896
#
# for BC TargetSet: 219
# for PageRank TargetSet: 222
# for closeness_centrality TargetSet: 232
# for EigenDegree TargetSet: 236
# for MDH TargetSet: 216
#
# ------ ER_1000_20_1 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001645     0.001000              0.379084     0.030802
# std       0.000745     0.000184              0.009883     0.007162
# min       0.000122     0.000412              0.334114     0.008228
# 25%       0.001094     0.000872              0.372483     0.025686
# 50%       0.001548     0.000998              0.379127     0.030418
# 75%       0.002057     0.001125              0.385714     0.035432
# max       0.004967     0.001635              0.411619     0.056253
#
# for BC TargetSet: 232
# for PageRank TargetSet: 226
# for closeness_centrality TargetSet: 245
# for EigenDegree TargetSet: 241
# for MDH TargetSet: 237
#
# ------ ER_1000_20_2 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001658     0.001000              0.377710     0.030729
# std       0.000773     0.000191              0.010052     0.007470
# min       0.000209     0.000537              0.346274     0.012008
# 25%       0.001104     0.000876              0.370962     0.025461
# 50%       0.001547     0.000981              0.377408     0.030239
# 75%       0.002107     0.001113              0.384712     0.035585
# max       0.005152     0.001610              0.408589     0.057820
#
# for BC TargetSet: 228
# for PageRank TargetSet: 224
# for closeness_centrality TargetSet: 232
# for EigenDegree TargetSet: 243
# for MDH TargetSet: 224
#
# ------ ER_1000_20_3 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001646     0.001000              0.378664     0.030788
# std       0.000741     0.000182              0.009833     0.007221
# min       0.000114     0.000446              0.340375     0.009506
# 25%       0.001125     0.000877              0.372206     0.025806
# 50%       0.001538     0.000999              0.378840     0.030608
# 75%       0.002074     0.001125              0.385008     0.035437
# max       0.005790     0.001634              0.410773     0.056976
#
# for BC TargetSet: 227
# for PageRank TargetSet: 227
# for closeness_centrality TargetSet: 241
# for EigenDegree TargetSet: 249
# for MDH TargetSet: 236
#
# ------ ER_2000_10_0 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001279     0.000500              0.282531     0.020991
# std       0.000843     0.000132              0.011696     0.007708
# min       0.000012     0.000158              0.228144     0.002463
# 25%       0.000640     0.000409              0.275325     0.015550
# 50%       0.001117     0.000495              0.282944     0.020116
# 75%       0.001738     0.000582              0.290468     0.025717
# max       0.007906     0.001108              0.324197     0.063502
#
# for BC TargetSet: 357
# for PageRank TargetSet: 326
# for closeness_centrality TargetSet: 377
# for EigenDegree TargetSet: 374
# for MDH TargetSet: 331
#
# ------ ER_2000_10_1 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001281     0.000500              0.280630     0.021041
# std       0.000853     0.000129              0.011580     0.007570
# min       0.000000     0.000118              0.220738     0.001993
# 25%       0.000666     0.000412              0.274098     0.015887
# 50%       0.001101     0.000497              0.281589     0.020514
# 75%       0.001729     0.000583              0.288331     0.025747
# max       0.005384     0.000970              0.315449     0.056776
#
# for BC TargetSet: 351
# for PageRank TargetSet: 328
# for closeness_centrality TargetSet: 369
# for EigenDegree TargetSet: 375
# for MDH TargetSet: 328
#
# ------ ER_2000_10_2 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001280     0.000500              0.280057     0.020933
# std       0.000872     0.000133              0.011950     0.007864
# min       0.000000     0.000125              0.212456     0.001317
# 25%       0.000650     0.000414              0.272938     0.015376
# 50%       0.001097     0.000499              0.280620     0.020224
# 75%       0.001735     0.000585              0.287833     0.025366
# max       0.007549     0.001047              0.318261     0.058222
#
# for BC TargetSet: 369
# for PageRank TargetSet: 333
# for closeness_centrality TargetSet: 391
# for EigenDegree TargetSet: 382
# for MDH TargetSet: 336
#
# ------ ER_2000_10_3 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001281     0.000500              0.280991     0.021012
# std       0.000850     0.000132              0.011717     0.007651
# min       0.000000     0.000126              0.215828     0.001453
# 25%       0.000650     0.000412              0.274061     0.015596
# 50%       0.001117     0.000497              0.281589     0.020412
# 75%       0.001705     0.000583              0.289082     0.025995
# max       0.006258     0.001029              0.316097     0.059853
#
# for BC TargetSet: 347
# for PageRank TargetSet: 331
# for closeness_centrality TargetSet: 374
# for EigenDegree TargetSet: 368
# for MDH TargetSet: 330
#
# ------ ER_2000_15_0 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001047     0.000500              0.324459     0.021473
# std       0.000606     0.000111              0.012245     0.006240
# min       0.000020     0.000135              0.263165     0.002827
# 25%       0.000609     0.000419              0.317138     0.017146
# 50%       0.000948     0.000500              0.325623     0.021183
# 75%       0.001337     0.000565              0.333167     0.025494
# max       0.005451     0.000944              0.358308     0.050481
#
# for BC TargetSet: 412
# for PageRank TargetSet: 392
# for closeness_centrality TargetSet: 439
# for EigenDegree TargetSet: 434
# for MDH TargetSet: 395
#
# ------ ER_2000_15_1 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001033     0.000500              0.326349     0.021469
# std       0.000581     0.000110              0.011925     0.006254
# min       0.000054     0.000214              0.279894     0.005503
# 25%       0.000614     0.000418              0.319125     0.017174
# 50%       0.000915     0.000495              0.327222     0.021044
# 75%       0.001351     0.000574              0.334785     0.025394
# max       0.004018     0.000876              0.357283     0.047163
#
# for BC TargetSet: 412
# for PageRank TargetSet: 399
# for closeness_centrality TargetSet: 430
# for EigenDegree TargetSet: 423
# for MDH TargetSet: 397
#
# ------ ER_2000_15_2 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count
, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.000912     0.000500              0.354452     0.021768
# std       0.000438     0.000092              0.007639     0.005117
# min       0.000065     0.000225              0.314506     0.006849
# 25%       0.000591     0.000434              0.349659     0.018031
# 50%       0.000854     0.000496              0.355031     0.021425
# 75%       0.001169     0.000560              0.359856     0.025207
# max       0.003007     0.000828              0.375752     0.040224
#
# for BC TargetSet: 463
# for PageRank TargetSet: 462
# for closeness_centrality TargetSet: 487
# for EigenDegree TargetSet: 481
# for MDH TargetSet: 467
#
# ------ ER_5000_10_0 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000593     0.000200              0.252476     0.013314
# std       0.000420     0.000052              0.010007     0.004770
# min       0.000000     0.000047              0.187039     0.000466
# 25%       0.000289     0.000165              0.246605     0.009909
# 50%       0.000508     0.000199              0.253640     0.012993
# 75%       0.000792     0.000234              0.259473     0.016311
# max       0.003596     0.000442              0.279915     0.037709
#
# for BC TargetSet: 898
# for PageRank TargetSet: 801
# for closeness_centrality TargetSet: 908
# for EigenDegree TargetSet: 911
# for MDH TargetSet: 813
#
# ------ ER_5000_10_1 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000583     0.000200              0.255270     0.013305
# std       0.000424     0.000053              0.010098     0.004795
# min       0.000000     0.000048              0.191327     0.000546
# 25%       0.000274     0.000163              0.249386     0.009877
# 50%       0.000489     0.000198              0.256550     0.013017
# 75%       0.000784     0.000232              0.262263     0.016220
# max       0.003367     0.000398              0.279180     0.032742
#
# for BC TargetSet: 887
# for PageRank TargetSet: 813
# for closeness_centrality TargetSet: 912
# for EigenDegree TargetSet: 901
# for MDH TargetSet: 822
#
# ------ ER_5000_10_2 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000590     0.000200              0.253747     0.013262
# std       0.000423     0.000053              0.010147     0.004910
# min       0.000000     0.000048              0.201443     0.001016
# 25%       0.000277     0.000164              0.247671     0.009750
# 50%       0.000485     0.000198              0.254480     0.012749
# 75%       0.000793     0.000233              0.260908     0.016275
# max       0.003555     0.000415              0.285919     0.041722
#
# for BC TargetSet: 891
# for PageRank TargetSet: 805
# for closeness_centrality TargetSet: 924
# for EigenDegree TargetSet: 911
# for MDH TargetSet: 812
#
# ------ ER_5000_10_3 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000586     0.000200              0.254207     0.013269
# std       0.000425     0.000053              0.010076     0.004892
# min       0.000000     0.000047              0.202791     0.001123
# 25%       0.000276     0.000164              0.248077     0.009764
# 50%       0.000487     0.000198              0.255129     0.012796
# 75%       0.000784     0.000233              0.261386     0.016326
# max       0.004273     0.000498              0.286213     0.045545
#
# for BC TargetSet: 887
# for PageRank TargetSet: 795
# for closeness_centrality TargetSet: 932
# for EigenDegree TargetSet: 923
# for MDH TargetSet: 817
#
# ------ ER_5000_15_0 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000489     0.000200              0.290076     0.013606
# std       0.000298     0.000043              0.008895     0.003856
# min       0.000007     0.000065              0.246414     0.002084
# 25%       0.000268     0.000168              0.284179     0.010911
# 50%       0.000431     0.000199              0.290336     0.013407
# 75%       0.000648     0.000230              0.296224     0.016096
# max       0.002461     0.000366              0.320161     0.031009
#
# for BC TargetSet: 1058
# for PageRank TargetSet: 987
# for closeness_centrality TargetSet: 1094
# for EigenDegree TargetSet: 1072
# for MDH TargetSet: 994
#
# ------ ER_5000_15_1 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000490     0.000200              0.290627     0.013621
# std       0.000299     0.000043              0.008848     0.003803
# min       0.000002     0.000055              0.238958     0.001583
# 25%       0.000274     0.000169              0.284778     0.010945
# 50%       0.000433     0.000198              0.291020     0.013477
# 75%       0.000643     0.000230              0.296809     0.016092
# max       0.002199     0.000345              0.317982     0.028660
#
# for BC TargetSet: 1077
# for PageRank TargetSet: 995
# for closeness_centrality TargetSet: 1088
# for EigenDegree TargetSet: 1083
# for MDH TargetSet: 1020
#
# ------ ER_5000_15_2 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000493     0.000200              0.289760     0.013616
# std       0.000299     0.000043              0.008745     0.003821
# min       0.000002     0.000057              0.233533     0.001221
# 25%       0.000272     0.000169              0.283986     0.010921
# 50%       0.000439     0.000199              0.289915     0.013344
# 75%       0.000645     0.000225              0.295624     0.016031
# max       0.002600     0.000386              0.324927     0.034441
#
# for BC TargetSet: 1062
# for PageRank TargetSet: 978
# for closeness_centrality TargetSet: 1094
# for EigenDegree TargetSet: 1081
# for MDH TargetSet: 1000
#
# ------ ER_5000_15_3 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000491     0.000200              0.289585     0.013592
# std       0.000307     0.000044              0.008912     0.003907
# min       0.000014     0.000076              0.252730     0.002774
# 25%       0.000265     0.000168              0.283756     0.010855
# 50%       0.000426     0.000199              0.289730     0.013358
# 75%       0.000650     0.000227              0.295711     0.016040
# max       0.002127     0.000380              0.319507     0.029747
#
# for BC TargetSet: 1068
# for PageRank TargetSet: 986
# for closeness_centrality TargetSet: 1079
# for EigenDegree TargetSet: 1080
# for MDH TargetSet: 998
#
# ------ ER_5000_20_0 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000426     0.000200              0.319584     0.013753
# std       0.000237     0.000038              0.009333     0.003296
# min       0.000011     0.000075              0.272381     0.003005
# 25%       0.000252     0.000175              0.313614     0.011374
# 50%       0.000384     0.000200              0.320428     0.013629
# 75%       0.000553     0.000226              0.326156     0.015865
# max       0.001960     0.000369              0.346623     0.029262
# for BC TargetSet: 1168
# for PageRank TargetSet: 1099
# for closeness_centrality TargetSet: 1185
# for EigenDegree TargetSet: 1197
# for MDH TargetSet: 1115
#
# ------ ER_5000_20_1 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000425     0.000200              0.320209     0.013751
# std       0.000233     0.000038              0.009414     0.003304
# min       0.000019     0.000074              0.274158     0.003113
# 25%       0.000252     0.000174              0.314383     0.011437
# 50%       0.000383     0.000200              0.320984     0.013615
# 75%       0.000552     0.000225              0.326903     0.015860
# max       0.001964     0.000350              0.347418     0.028986
#
# for BC TargetSet: 1206
# for PageRank TargetSet: 1128
# for closeness_centrality TargetSet: 1210
# for EigenDegree TargetSet: 1213
# for MDH TargetSet: 1146
#
# ------ ER_5000_20_2 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000426     0.000200              0.320172     0.013764
# std       0.000232     0.000037              0.009348     0.003247
# min       0.000012     0.000074              0.269983     0.002576
# 25%       0.000257     0.000174              0.314496     0.011514
# 50%       0.000385     0.000200              0.321211     0.013708
# 75%       0.000557     0.000225              0.326844     0.015938
# max       0.001826     0.000350              0.346215     0.028329
#
# for BC TargetSet: 1198
# for PageRank TargetSet: 1122
# for closeness_centrality TargetSet: 1195
# for EigenDegree TargetSet: 1189
# for MDH TargetSet: 1130
#
# ------ ER_5000_20_3 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000423     0.000200              0.320998     0.013742
# std       0.000233     0.000038              0.009456     0.003340
# min       0.000015     0.000080              0.282701     0.004349
# 25%       0.000255     0.000174              0.315215     0.011421
# 50%       0.000380     0.000198              0.321707     0.013533
# 75%       0.000550     0.000225              0.327680     0.015875
# max       0.001733     0.000386              0.346912     0.028392
#
# for BC TargetSet: 1176
# for PageRank TargetSet: 1110
# for closeness_centrality TargetSet: 1201
# for EigenDegree TargetSet: 1189
# for MDH TargetSet: 1126

# %%
Trials = graphs.copy()

#Res = {t:[] for t in Trials}
for trial in Trials:
    print(f"\n------ {trial} ------\n")
    if len(trial) == 13:
        file = "./BRKGA/instances/Erdos/test/feats/"+trial+"_feat.txt"
        file_graph = "./BRKGA/instances/Erdos/test/txt/"+trial+".txt"
        #Res[trial] = CheckAll(file, file_graph)
    else:
        file = "./BRKGA/instances/Erdos/train/feats/"+trial+"_feat.txt"
        file_graph = "./BRKGA/instances/Erdos/train/txt/"+trial+".txt"
        Res[trial] = CheckAll(file, file_graph)
# Out:
# ------ ER_10000_10_0 ------
#
#
# ------ ER_10000_10_1 ------
#
#
# ------ ER_10000_15_0 ------
#
#
# ------ ER_10000_15_1 ------
#
#
# ------ ER_10000_20_0 ------
#
#
# ------ ER_10000_20_1 ------
#
#
# ------ ER_20000_10_0 ------
#
#
# ------ ER_20000_10_1 ------
#
#
# ------ ER_20000_15_0 ------
#
#
# ------ ER_20000_15_1 ------
#
#
# ------ ER_20000_20_0 ------
#
#
# ------ ER_20000_20_1 ------
#
#
# ------ ER_30000_10_0 ------
#
#
# ------ ER_30000_15_0 ------
#
#
# ------ ER_30000_20_0 ------
#
#
# ------ ER_50000_10_0 ------
#
#
# ------ ER_50000_15_0 ------
#
#
# ------ ER_50000_20_0 ------
#
#
# ------ ER_1000_10_0 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.002251     0.001000              0.308173     0.029697
# std       0.001427     0.000271              0.015228     0.010872
# min       0.000023     0.000316              0.254782     0.005160
# 25%       0.001198     0.000819              0.298833     0.022215
# 50%       0.002012     0.000997              0.309671     0.029269
# 75%       0.003031     0.001167              0.318787     0.036712
# max       0.010424     0.002146              0.354004     0.087596
#
# for BC TargetSet: 165
# for PageRank TargetSet: 157
# for closeness_centrality TargetSet: 170
# for EigenDegree TargetSet: 181
# for MDH TargetSet: 162
#
# ------ ER_1000_10_1 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.002286     0.001000              0.305725     0.029672
# std       0.001488     0.000266              0.014619     0.010940
# min       0.000042     0.000331              0.247952     0.004546
# 25%       0.001215     0.000828              0.296000     0.021687
# 50%       0.002028     0.000994              0.306066     0.028323
# 75%       0.002948     0.001171              0.315964     0.036487
# max       0.009808     0.002088              0.344245     0.075252
#
# for BC TargetSet: 170
# for PageRank TargetSet: 162
# for closeness_centrality TargetSet: 177
# for EigenDegree TargetSet: 177
# for MDH TargetSet: 158
#
# ------ ER_1000_10_2 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.002230     0.001000              0.310392     0.029880
# std       0.001406     0.000254              0.014354     0.010358
# min       0.000126     0.000324              0.262895     0.006389
# 25%       0.001212     0.000817              0.301448     0.022671
# 50%       0.001893     0.000981              0.310731     0.028805
# 75%       0.003007     0.001155              0.320706     0.036380
# max       0.008820     0.001930              0.350649     0.073053
#
# for BC TargetSet: 176
# for PageRank TargetSet: 170
# for closeness_centrality TargetSet: 189
# for EigenDegree TargetSet: 186
# for MDH TargetSet: 177
#
# ------ ER_1000_10_3 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.002272     0.001000              0.307022     0.029715
# std       0.001447     0.000259              0.014761     0.010824
# min       0.000000     0.000248              0.230025     0.002223
# 25%       0.001239     0.000830              0.297476     0.021969
# 50%       0.002001     0.000995              0.307479     0.028821
# 75%       0.002945     0.001160              0.317244     0.036511
# max       0.012217     0.002270              0.352381     0.082269
#
# for BC TargetSet: 170
# for PageRank TargetSet: 163
# for closeness_centrality TargetSet: 182
# for EigenDegree TargetSet: 182
# for MDH TargetSet: 162
#
# ------ ER_1000_15_0 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001812     0.001000              0.356374     0.030505
# std       0.000958     0.000214              0.011011     0.008339
# min       0.000124     0.000429              0.314151     0.010077
# 25%       0.001098     0.000832              0.349790     0.024527
# 50%       0.001685     0.000990              0.357424     0.030025
# 75%       0.002346     0.001145              0.363802     0.035775
# max       0.007175     0.001874              0.385714     0.064632
#
# for BC TargetSet: 209
# for PageRank TargetSet: 199
# for closeness_centrality TargetSet: 213
# for EigenDegree TargetSet: 219
# for MDH TargetSet: 202
#
# ------ ER_1000_15_1 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001826     0.001000              0.354325     0.030521
# std       0.000963     0.000217              0.011367     0.008277
# min       0.000074     0.000327              0.292533     0.005995
# 25%       0.001110     0.000842              0.348175     0.025053
# 50%       0.001667     0.000992              0.355453     0.030196
# 75%       0.002345     0.001137              0.361825     0.035708
# max       0.006638     0.001736              0.383199     0.059866
#
# for BC TargetSet: 196
# for PageRank TargetSet: 190
# for closeness_centrality TargetSet: 220
# for EigenDegree TargetSet: 217
# for MDH TargetSet: 190
#
# ------ ER_1000_15_2 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001834     0.001000              0.353609     0.030433
# std       0.000985     0.000221              0.011554     0.008598
# min       0.000202     0.000434              0.305131     0.009601
# 25%       0.001082     0.000840              0.346634     0.024327
# 50%       0.001673     0.001002              0.354570     0.030020
# 75%       0.002346     0.001134              0.361564     0.035880
# max       0.006713     0.001828              0.383346     0.062728
#
# for BC TargetSet: 206
# for PageRank TargetSet: 194
# for closeness_centrality TargetSet: 204
# for EigenDegree TargetSet: 203
# for MDH TargetSet: 197
#
# ------ ER_1000_15_3 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001820     0.001000              0.354705     0.030498
# std       0.000907     0.000210              0.011197     0.008363
# min       0.000011     0.000323              0.291254     0.006453
# 25%       0.001151     0.000844              0.348084     0.024594
# 50%       0.001694     0.000997              0.355516     0.029776
# 75%       0.002386     0.001153              0.362877     0.036199
# max       0.005966     0.001751              0.382612     0.061401
#
# for BC TargetSet: 208
# for PageRank TargetSet: 202
# for closeness_centrality TargetSet: 217
# for EigenDegree TargetSet: 219
# for MDH TargetSet: 205
#
# ------ ER_1000_20_0 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001650     0.001000              0.377927     0.030757
# std       0.000763     0.000189              0.009866     0.007353
# min       0.000135     0.000502              0.343299     0.011545
# 25%       0.001054     0.000853              0.370824     0.025164
# 50%       0.001533     0.000978              0.377837     0.030214
# 75%       0.002132     0.001138              0.385008     0.036021
# max       0.005183     0.001595              0.404290     0.051896
#
# for BC TargetSet: 219
# for PageRank TargetSet: 222
# for closeness_centrality TargetSet: 232
# for EigenDegree TargetSet: 236
# for MDH TargetSet: 216
#
# ------ ER_1000_20_1 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001645     0.001000              0.379084     0.030802
# std       0.000745     0.000184              0.009883     0.007162
# min       0.000122     0.000412              0.334114     0.008228
# 25%       0.001094     0.000872              0.372483     0.025686
# 50%       0.001548     0.000998              0.379127     0.030418
# 75%       0.002057     0.001125              0.385714     0.035432
# max       0.004967     0.001635              0.411619     0.056253
#
# for BC TargetSet: 232
# for PageRank TargetSet: 226
# for closeness_centrality TargetSet: 245
# for EigenDegree TargetSet: 241
# for MDH TargetSet: 237
#
# ------ ER_1000_20_2 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001658     0.001000              0.377710     0.030729
# std       0.000773     0.000191              0.010052     0.007470
# min       0.000209     0.000537              0.346274     0.012008
# 25%       0.001104     0.000876              0.370962     0.025461
# 50%       0.001547     0.000981              0.377408     0.030239
# 75%       0.002107     0.001113              0.384712     0.035585
# max       0.005152     0.001610              0.408589     0.057820
#
# for BC TargetSet: 228
# for PageRank TargetSet: 224
# for closeness_centrality TargetSet: 232
# for EigenDegree TargetSet: 243
# for MDH TargetSet: 224
#
# ------ ER_1000_20_3 ------
#
# (1000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  1000.000000  1000.000000           1000.000000  1000.000000
# mean      0.001646     0.001000              0.378664     0.030788
# std       0.000741     0.000182              0.009833     0.007221
# min       0.000114     0.000446              0.340375     0.009506
# 25%       0.001125     0.000877              0.372206     0.025806
# 50%       0.001538     0.000999              0.378840     0.030608
# 75%       0.002074     0.001125              0.385008     0.035437
# max       0.005790     0.001634              0.410773     0.056976
#
# for BC TargetSet: 227
# for PageRank TargetSet: 227
# for closeness_centrality TargetSet: 241
# for EigenDegree TargetSet: 249
# for MDH TargetSet: 236
#
# ------ ER_2000_10_0 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001279     0.000500              0.282531     0.020991
# std       0.000843     0.000132              0.011696     0.007708
# min       0.000012     0.000158              0.228144     0.002463
# 25%       0.000640     0.000409              0.275325     0.015550
# 50%       0.001117     0.000495              0.282944     0.020116
# 75%       0.001738     0.000582              0.290468     0.025717
# max       0.007906     0.001108              0.324197     0.063502
#
# for BC TargetSet: 357
# for PageRank TargetSet: 326
# for closeness_centrality TargetSet: 377
# for EigenDegree TargetSet: 374
# for MDH TargetSet: 331
#
# ------ ER_2000_10_1 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001281     0.000500              0.280630     0.021041
# std       0.000853     0.000129              0.011580     0.007570
# min       0.000000     0.000118              0.220738     0.001993
# 25%       0.000666     0.000412              0.274098     0.015887
# 50%       0.001101     0.000497              0.281589     0.020514
# 75%       0.001729     0.000583              0.288331     0.025747
# max       0.005384     0.000970              0.315449     0.056776
#
# for BC TargetSet: 351
# for PageRank TargetSet: 328
# for closeness_centrality TargetSet: 369
# for EigenDegree TargetSet: 375
# for MDH TargetSet: 328
#
# ------ ER_2000_10_2 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001280     0.000500              0.280057     0.020933
# std       0.000872     0.000133              0.011950     0.007864
# min       0.000000     0.000125              0.212456     0.001317
# 25%       0.000650     0.000414              0.272938     0.015376
# 50%       0.001097     0.000499              0.280620     0.020224
# 75%       0.001735     0.000585              0.287833     0.025366
# max       0.007549     0.001047              0.318261     0.058222
#
# for BC TargetSet: 369
# for PageRank TargetSet: 333
# for closeness_centrality TargetSet: 391
# for EigenDegree TargetSet: 382
# for MDH TargetSet: 336
#
# ------ ER_2000_10_3 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.001281     0.000500              0.280991     0.021012
# std       0.000850     0.000132              0.011717     0.007651
# min       0.000000     0.000126              0.215828     0.001453
# 25%       0.000650     0.000412              0.274061     0.015596
# 50%       0.001117     0.000497              0.281589     0.020412
# 75%       0.001705     0.000583              0.289082     0.025995
# max       0.006258     0.001029              0.316097     0.059853
#
# for BC TargetSet: 347
# for PageRank TargetSet: 331
# for closeness_centrality TargetSet: 374
# for EigenDegree TargetSet: 368
# for MDH TargetSet: 330
#
# ------ ER_2000_15_0 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count
, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.000913     0.000500              0.353968     0.021707
# std       0.000461     0.000097              0.008173     0.005367
# min       0.000018     0.000181              0.303292     0.005382
# 25%       0.000574     0.000433              0.349109     0.017946
# 50%       0.000836     0.000497              0.354716     0.021399
# 75%       0.001171     0.000561              0.359726     0.025351
# max       0.004122     0.000938              0.381561     0.045763
#
# for BC TargetSet: 454
# for PageRank TargetSet: 448
# for closeness_centrality TargetSet: 476
# for EigenDegree TargetSet: 479
# for MDH TargetSet: 451
#
# ------ ER_2000_20_2 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.000914     0.000500              0.354073     0.021738
# std       0.000457     0.000095              0.007864     0.005240
# min       0.000134     0.000226              0.315598     0.006804
# 25%       0.000582     0.000434              0.349353     0.018001
# 50%       0.000824     0.000495              0.354495     0.021374
# 75%       0.001174     0.000560              0.359549     0.025213
# max       0.003151     0.000850              0.378026     0.042289
#
# for BC TargetSet: 471
# for PageRank TargetSet: 448
# for closeness_centrality TargetSet: 490
# for EigenDegree TargetSet: 482
# for MDH TargetSet: 463
#
# ------ ER_2000_20_3 ------
#
# (2000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  2000.000000  2000.000000           2000.000000  2000.000000
# mean      0.000912     0.000500              0.354452     0.021768
# std       0.000438     0.000092              0.007639     0.005117
# min       0.000065     0.000225              0.314506     0.006849
# 25%       0.000591     0.000434              0.349659     0.018031
# 50%       0.000854     0.000496              0.355031     0.021425
# 75%       0.001169     0.000560              0.359856     0.025207
# max       0.003007     0.000828              0.375752     0.040224
#
# for BC TargetSet: 463
# for PageRank TargetSet: 462
# for closeness_centrality TargetSet: 487
# for EigenDegree TargetSet: 481
# for MDH TargetSet: 467
#
# ------ ER_5000_10_0 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000593     0.000200              0.252476     0.013314
# std       0.000420     0.000052              0.010007     0.004770
# min       0.000000     0.000047              0.187039     0.000466
# 25%       0.000289     0.000165              0.246605     0.009909
# 50%       0.000508     0.000199              0.253640     0.012993
# 75%       0.000792     0.000234              0.259473     0.016311
# max       0.003596     0.000442              0.279915     0.037709
#
# for BC TargetSet: 898
# for PageRank TargetSet: 801
# for closeness_centrality TargetSet: 908
# for EigenDegree TargetSet: 911
# for MDH TargetSet: 813
#
# ------ ER_5000_10_1 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000583     0.000200              0.255270     0.013305
# std       0.000424     0.000053              0.010098     0.004795
# min       0.000000     0.000048              0.191327     0.000546
# 25%       0.000274     0.000163              0.249386     0.009877
# 50%       0.000489     0.000198              0.256550     0.013017
# 75%       0.000784     0.000232              0.262263     0.016220
# max       0.003367     0.000398              0.279180     0.032742
#
# for BC TargetSet: 887
# for PageRank TargetSet: 813
# for closeness_centrality TargetSet: 912
# for EigenDegree TargetSet: 901
# for MDH TargetSet: 822
#
# ------ ER_5000_10_2 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000590     0.000200              0.253747     0.013262
# std       0.000423     0.000053              0.010147     0.004910
# min       0.000000     0.000048              0.201443     0.001016
# 25%       0.000277     0.000164              0.247671     0.009750
# 50%       0.000485     0.000198              0.254480     0.012749
# 75%       0.000793     0.000233              0.260908     0.016275
# max       0.003555     0.000415              0.285919     0.041722
#
# for BC TargetSet: 891
# for PageRank TargetSet: 805
# for closeness_centrality TargetSet: 924
# for EigenDegree TargetSet: 911
# for MDH TargetSet: 812
#
# ------ ER_5000_10_3 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000586     0.000200              0.254207     0.013269
# std       0.000425     0.000053              0.010076     0.004892
# min       0.000000     0.000047              0.202791     0.001123
# 25%       0.000276     0.000164              0.248077     0.009764
# 50%       0.000487     0.000198              0.255129     0.012796
# 75%       0.000784     0.000233              0.261386     0.016326
# max       0.004273     0.000498              0.286213     0.045545
#
# for BC TargetSet: 887
# for PageRank TargetSet: 795
# for closeness_centrality TargetSet: 932
# for EigenDegree TargetSet: 923
# for MDH TargetSet: 817
#
# ------ ER_5000_15_0 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000489     0.000200              0.290076     0.013606
# std       0.000298     0.000043              0.008895     0.003856
# min       0.000007     0.000065              0.246414     0.002084
# 25%       0.000268     0.000168              0.284179     0.010911
# 50%       0.000431     0.000199              0.290336     0.013407
# 75%       0.000648     0.000230              0.296224     0.016096
# max       0.002461     0.000366              0.320161     0.031009
#
# for BC TargetSet: 1058
# for PageRank TargetSet: 987
# for closeness_centrality TargetSet: 1094
# for EigenDegree TargetSet: 1072
# for MDH TargetSet: 994
#
# ------ ER_5000_15_1 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000490     0.000200              0.290627     0.013621
# std       0.000299     0.000043              0.008848     0.003803
# min       0.000002     0.000055              0.238958     0.001583
# 25%       0.000274     0.000169              0.284778     0.010945
# 50%       0.000433     0.000198              0.291020     0.013477
# 75%       0.000643     0.000230              0.296809     0.016092
# max       0.002199     0.000345              0.317982     0.028660
#
# for BC TargetSet: 1077
# for PageRank TargetSet: 995
# for closeness_centrality TargetSet: 1088
# for EigenDegree TargetSet: 1083
# for MDH TargetSet: 1020
#
# ------ ER_5000_15_2 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000493     0.000200              0.289760     0.013616
# std       0.000299     0.000043              0.008745     0.003821
# min       0.000002     0.000057              0.233533     0.001221
# 25%       0.000272     0.000169              0.283986     0.010921
# 50%       0.000439     0.000199              0.289915     0.013344
# 75%       0.000645     0.000225              0.295624     0.016031
# max       0.002600     0.000386              0.324927     0.034441
#
# for BC TargetSet: 1062
# for PageRank TargetSet: 978
# for closeness_centrality TargetSet: 1094
# for EigenDegree TargetSet: 1081
# for MDH TargetSet: 1000
#
# ------ ER_5000_15_3 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000491     0.000200              0.289585     0.013592
# std       0.000307     0.000044              0.008912     0.003907
# min       0.000014     0.000076              0.252730     0.002774
# 25%       0.000265     0.000168              0.283756     0.010855
# 50%       0.000426     0.000199              0.289730     0.013358
# 75%       0.000650     0.000227              0.295711     0.016040
# max       0.002127     0.000380              0.319507     0.029747
# for BC TargetSet: 1068
# for PageRank TargetSet: 986
# for closeness_centrality TargetSet: 1079
# for EigenDegree TargetSet: 1080
# for MDH TargetSet: 998
#
# ------ ER_5000_20_0 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000426     0.000200              0.319584     0.013753
# std       0.000237     0.000038              0.009333     0.003296
# min       0.000011     0.000075              0.272381     0.003005
# 25%       0.000252     0.000175              0.313614     0.011374
# 50%       0.000384     0.000200              0.320428     0.013629
# 75%       0.000553     0.000226              0.326156     0.015865
# max       0.001960     0.000369              0.346623     0.029262
#
# for BC TargetSet: 1168
# for PageRank TargetSet: 1099
# for closeness_centrality TargetSet: 1185
# for EigenDegree TargetSet: 1197
# for MDH TargetSet: 1115
#
# ------ ER_5000_20_1 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000425     0.000200              0.320209     0.013751
# std       0.000233     0.000038              0.009414     0.003304
# min       0.000019     0.000074              0.274158     0.003113
# 25%       0.000252     0.000174              0.314383     0.011437
# 50%       0.000383     0.000200              0.320984     0.013615
# 75%       0.000552     0.000225              0.326903     0.015860
# max       0.001964     0.000350              0.347418     0.028986
#
# for BC TargetSet: 1206
# for PageRank TargetSet: 1128
# for closeness_centrality TargetSet: 1210
# for EigenDegree TargetSet: 1213
# for MDH TargetSet: 1146
#
# ------ ER_5000_20_2 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000426     0.000200              0.320172     0.013764
# std       0.000232     0.000037              0.009348     0.003247
# min       0.000012     0.000074              0.269983     0.002576
# 25%       0.000257     0.000174              0.314496     0.011514
# 50%       0.000385     0.000200              0.321211     0.013708
# 75%       0.000557     0.000225              0.326844     0.015938
# max       0.001826     0.000350              0.346215     0.028329
#
# for BC TargetSet: 1198
# for PageRank TargetSet: 1122
# for closeness_centrality TargetSet: 1195
# for EigenDegree TargetSet: 1189
# for MDH TargetSet: 1130
#
# ------ ER_5000_20_3 ------
#
# (5000, 4)
#                 BC     PageRank  closeness_centrality  EigenDegree
# count  5000.000000  5000.000000           5000.000000  5000.000000
# mean      0.000423     0.000200              0.320998     0.013742
# std       0.000233     0.000038              0.009456     0.003340
# min       0.000015     0.000080              0.282701     0.004349
# 25%       0.000255     0.000174              0.315215     0.011421
# 50%       0.000380     0.000198              0.321707     0.013533
# 75%       0.000550     0.000225              0.327680     0.015875
# max       0.001733     0.000386              0.346912     0.028392
#
# for BC TargetSet: 1176
# for PageRank TargetSet: 1110
# for closeness_centrality TargetSet: 1201
# for EigenDegree TargetSet: 1189
# for MDH TargetSet: 1126

# %%
ResEr = pd.DataFrame(Res).T
ResEr.columns = ["BC", "PageRank","closeness_centrality","EigenDegree","MDH" ,"size"]
ResEr.head()
# Out:
#                BC  PageRank  closeness_centrality  EigenDegree  MDH  size
# ER_1000_10_0  165       157                   170          181  162  1000
# ER_1000_10_1  170       162                   177          177  158  1000
# ER_1000_10_2  176       170                   189          186  177  1000
# ER_1000_10_3  170       163                   182          182  162  1000
# ER_1000_15_0  209       199                   213          219  202  1000

# %%
ResEr.to_csv("ErdosTrain_Diffusion_results_for_features.csv")

# %%
graphsFeatures[i]
# Out:
# './BRKGA/instances/Erdos/test/feats/ER_20000_20_0_feat.txt'

# %%
i = 10
PATH_TO_TRAIN = "./BRKGA/instances/Erdos/train/"
graphFeatures = [(PATH_TO_TRAIN+"feats/"+feat).replace(".txt", "")+"_feat.txt" for feat in os.listdir(PATH_TO_TRAIN+'txt')]

DataFeats = loadFeatures(graphFeatures[i], remove_degree = False)
for feat in DataFeats.columns:
    fig, ax = plt.subplots(figsize=(5,2)) 
    Standar(DataFeats[feat]).hist()
    name = graphFeatures[i].split("/")[-1]
    plt.title(f"{feat} for {name}")
    plt.show()

# %%
i = -1
PATH_TO_TRAIN = "./BRKGA/instances/Erdos/test/"
graphFeatures = [(PATH_TO_TRAIN+"feats/"+feat).replace(".txt", "")+"_feat.txt" for feat in os.listdir(PATH_TO_TRAIN+'txt')]

DataFeats = loadFeatures(graphFeatures[i], remove_degree = False)
for feat in DataFeats.columns:
    fig, ax = plt.subplots(figsize=(5,2)) 
    Standar(DataFeats[feat]).hist()
    name = graphFeatures[i].split("/")[-1]
    plt.title(f"{feat} for {name}")
    plt.show()

# %% [markdown]
# ## Pruebas de entrenamiento

# %%
def getDimParams(model):
    # Returns the number of parameters needed
    sum_ = 0
    for name, param in model.named_parameters():
        m = 1
        #print(name, param.shape)
        #print(np.max(param.detach().numpy()), np.min(param.detach().numpy()))
        for n in param.shape:
            m*=n
        sum_ += m
    return sum_ 

def getStateDict(model, params):
    # reensamble the original state dict with new values
    sd = model.state_dict()
    sum_ = 0
    from_ = 0

    for name, param in model.named_parameters():
        m = 1
        for n in param.shape:
            m*=n
        #print(m)
        #print(vals[from_:from_+m].reshape(param.shape).shape)
        sd[name] = torch.tensor(params[from_:from_+m].reshape(param.shape))
        from_ += m
        #print(from_)
    return sd

def SimpleweightedCrossEntropy(y, p, w):
    return np.sum(y*(1-p)*w[0] + (1-y)*p*w[1]) / len(y)

def Func(X, MDH = False, alpha = 0.7):
    # Objective function
    
    if not MDH:
        sd = getStateDict(Models[i], X)
        Models[i].load_state_dict(sd)
    else:
        alpha = 1
        
    
    value = 0.0
    loss = 0.0
    
    for ig, data in enumerate(Graphs_Train):
        
        if MDH:
            y_pred = None
        else:
            data = data.to(device)
            y_pred = torch.exp(Models[i](data)).T[1]
        
        
        ts = len(FindMinimumTarget(graphs[ig], out = y_pred, threshold = 0.5)[0])
        
        val = ts / graphs[ig].number_of_nodes()
        
        value += val
        
        #"""
        if not MDH:
            zeros = np.zeros(data.num_nodes)
            zeros[torch.topk(y_pred, ts)[1]] = 1
            weigth_minoritaria = np.sum(zeros==0)/np.sum(zeros)
            loss += SimpleweightedCrossEntropy(zeros, y_pred.detach().numpy(), [weigth_minoritaria, 1])
        
        #"""
        
        
    
    value /= len(Graphs_Train) 
    loss /= len(Graphs_Train) 
    #return value
    
    return value * (alpha) + loss * (1 - alpha)

# %%
def getDataSet(file, file_graph, scale, remove_BC = False):
    
    G = loadGraph(file_graph)
    Features = []
    temp = []
    try:
        with open(file) as f:
            c = 0

            for line in f.readlines()[1:]:
                c+=1
                feats = np.array(line.split(","), dtype = float)
                temp.append(feats)
        temp = np.array(temp)
        if remove_BC:
            temp = np.delete(temp, 0, 1)
        Features.append(temp)
    except Exception as e:
        print(er)
        print(line)
        print(c)
        print(e)

    Graphs_Train = Convert2DataSet([G], [[]], feats = Features, scale = scale)

    return Graphs_Train

# %%
SCL = True
PATH_TO_TRAIN = "./BRKGA/instances/scalefree/train/"
#PATH_TO_TRAIN = "./BRKGA/instances/Erdos/train/"

PATH_SAVE_TRAINS = "Models/runs/scalefree/GA/"

SEED = 13

max_iterations = 1
pop_size = 2
elitratio = 0.1
threshold = 0.5

dt_string = datetime.now().strftime("%m-%d_%H-%M")

Instances = [graph for graph in os.listdir(PATH_TO_TRAIN + 'txt')]
Instances.sort()

graphs = []
for er in Instances:
    graph = igraph.Graph.Read_Edgelist(PATH_TO_TRAIN+"txt/"+er, directed = False)
    graphs.append(graph.to_networkx())    

OptInstances = [graph for graph in os.listdir(PATH_TO_TRAIN+'optimal')]
OptInstances.sort()
Solutions = []

for er in OptInstances:
    opt = []
    with open(PATH_TO_TRAIN+'optimal/'+er) as f:
        for line in f.readlines():
            opt.append(int(line.replace("\n", "")))
    Solutions.append(opt)   


print("\nCargando Features...\n")
graphFeatures = [feat for feat in os.listdir(PATH_TO_TRAIN+'feats')]
graphFeatures.sort()
Features = []
for er in graphFeatures:
    temp = []
    try:
        with open(PATH_TO_TRAIN+'feats/'+er) as f:
            c = 0

            for line in f.readlines()[1:]:
                c+=1
                feats = np.array(line.split(","), dtype = float)
                temp.append(feats)
        temp = np.array(temp)
        #temp = np.delete(temp, 2, 1)
        Features.append(temp)
    except Excepcion as e:
        print(er)
        print(line)
        print(c)
        print(e)
    
Graphs_Train = Convert2DataSet(graphs, Solutions, feats = Features, scale = SCL)

num_features = Graphs_Train[0].num_features
num_classes = Graphs_Train[0].num_classes
# Out:
# Cargando Features...

# %%
import torch.nn as nn
import torch_geometric.nn as geom_nn
import torch.nn.functional as F
import torch
from torch_geometric.nn import Linear

class GNN(torch.nn.Module):
    def __init__(self, num_node_features, num_classes, name_layer = "SAGE"):
        super().__init__()
        self.name = name_layer
        layer = None
        hidden_feats = 8
        
        if name_layer == "SAGE":
            layer = geom_nn.SAGEConv
            
            self.conv1 = layer(num_node_features, hidden_feats)
            self.conv3 = layer(hidden_feats, num_classes)
            
        elif name_layer == "GAT":
            layer = geom_nn.GATConv
            
            self.conv1 = layer(num_node_features, num_classes)
            #self.conv3 = Linear(hidden_feats, num_classes)
            
        elif name_layer == "GCN":
            layer = geom_nn.GCNConv
            
            self.conv1 = layer(num_node_features, num_classes)
            #self.conv1 = layer(num_node_features, hidden_feats)
            #self.conv3 = Linear(hidden_feats, num_classes)
            
        elif name_layer == "GraphConv":
            layer = geom_nn.GraphConv
            
            self.conv1 = layer(num_node_features, num_classes)
            
        elif name_layer == "SGConv":
            layer = geom_nn.SGConv
            
            self.conv1 = layer(num_node_features, num_classes)
            #self.conv3 = Linear(hidden_feats, num_classes)
        
        
        else:
            print("Nanais")
    
        
        #self.conv2 = layer(hidden_feats, hidden_feats)
        #self.conv3 = Linear(hidden_feats, num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        x = self.conv3(x, edge_index)
        x = F.relu(x)

        #return F.log_softmax(self.conv3(x), dim=1)
        #if self.name in ['GraphConv', 'GCN', 'SAGE']:
        return F.log_softmax(x, dim=1)
        #else:
        #    return F.log_softmax(self.conv3(x), dim=1)

# %%
seed = 13
device = 'cpu'
layers = ["GCN", "GAT","GraphConv", "SAGE", "SGConv"]

torch.manual_seed(seed)
Models = [GNN(num_features, num_classes, name_layer = layer_name) for 
         layer_name in layers]

# %%
print(f"\nMDH value: {Func(_, MDH = True)}\n")

i = 3

varbound = np.array([[-10,10]] * getDimParams(Models[i]) )

algorithm_param = {'max_num_iteration' : 15,\
                   'population_size' : 10,\
                   'mutation_probability' : 0.4,\
                   'elit_ratio': 0.01,\
                   'crossover_probability': 0.5,\
                   'parents_portion': 0.3,\
                   'crossover_type' : 'uniform',\
                   'max_iteration_without_improv' : 100//2}

GA_model = ga(function = Func,\
            dimension = getDimParams(Models[i]),\
            variable_type = 'real',\
            variable_boundaries = varbound,\
            algorithm_parameters = algorithm_param,
            function_timeout = 1_000,
            convergence_curve = True)

GA_model.run()

sd = getStateDict(Models[i], GA_model.best_variable)
Models[i].load_state_dict(sd)
# 0.1983
# Out:
# MDH value: 0.10980000000000001
#
#  The best solution found:
#  [-8.97302947 -0.88116901 -7.00597884  1.98431877 -9.90381837  3.45336161
#   9.70968855  1.81714487  7.14404303  0.2929957  -3.33149597 -4.70547549
#  -1.45735887 -9.16877804 -7.32916857  7.0532832   0.56085792  7.34218453
#  -1.33788629 -5.89435213 -0.54247137 -0.68163597 -7.00683888  2.21191042
#  -8.05925628 -6.79462122  6.76220451  5.95604308 -8.72197767  8.75355904
#  -7.48760738 -6.22247163 -1.08496763 -8.74886435  3.15695222  4.25276274
#  -6.39752151  0.95861989 -6.69856318 -6.05205478  9.40633364  6.4220834
#  -9.0364737  -5.50231376  2.47406571  5.85064695 -4.09921224  7.41217413
#   6.49978775  9.74144692 -4.04481818 -7.25272655 -1.13424199 -7.32398918
#   9.9020538   7.19754606  5.54253508  8.99898667 -2.0427853  -3.91043523
#  -0.8802249  -7.95746569 -7.39740714  1.56135021  3.73767584  1.77461146
#   0.91937356  2.74886292 -8.4581334   8.5196237   4.09064004  8.78585278
#   0.87187277  0.91515965  9.57090567 -7.92271893 -5.53466638 -5.5869279
#  -1.9633465  -9.83039442 -9.70874253  2.88503356 -7.41460635  6.90853747
#   5.79599453  6.97454327  5.31400472 -2.69209879  7.02410431 -1.36538434
#  -0.7661674  -0.05267118 -8.80260871  1.82427898  7.4406148   8.45859682
#  -5.31645095 -4.51455056 -0.24119944 -9.91764419  7.33281828  9.43276345
#   7.23153139  4.92887064 -6.07365382 -8.3189846   6.65012041  8.16703084
#  -8.80249493 -6.9285411   3.33743121 -2.86879644 -4.43181553 -9.00731871
#  -9.84748519 -2.56770741 -6.87507689  8.55686953  9.76155129  8.42717695
#  -1.50510293  9.75165469 -2.30452749 -9.34374837 -9.05285312  5.20481808
#   8.12926088  1.60995919  9.13140476  7.94640298  3.80552372 -3.34358444
#   1.04724107  7.44837048  6.8232403  -7.99164537 -9.9696088   4.59714359
#  -4.89317674  7.98461975  0.44678439 -1.89451389 -8.74829867  6.61318527
#   0.57692111  3.56495254  4.7961467  -7.50410852 -0.84621221  7.94561238
#  -2.60302103 -0.8684253  -1.99014893 -1.20680787  7.33254968  2.63798626
#  -1.32520536  8.09818971  5.61944433  9.16031716 -3.86994466 -3.02294297
#   1.24614513 -4.30203752 -5.09098048 -2.40840345  2.66848147 -7.78367905
#  -5.67915862  7.13330792  2.24922098 -2.28394839  7.60913672 -6.34614721
#  -9.38927519 -0.82693469  0.23497147  0.67432855  7.10424359 -6.15078813
#  -0.0376626   4.43891853  6.84382424  4.61794687 -4.57870983  8.48420881
#  -7.15144821  6.70333049 -5.79768972 -5.7009809  -7.31711706 -1.91664913
#   3.35374114  6.8723797   2.90437454 -0.34363417 -9.45280041  5.49253228
#  -9.54540878 -3.09271695 -3.85548308 -9.43876817 -8.86349938  8.76118531
#   3.46738345  7.29865886  9.19473995  7.16967961  9.30288807  2.94374905
#   9.32407315 -4.18882961 -5.13139463  0.94044248  0.50742906 -3.46571684
#  -0.62147837  7.51627472  4.02276059  9.50291683 -8.29092464 -3.55322298
#   1.02432325 -8.81200339  8.130163    0.97554509  1.78742129  7.32386155
#  -0.82503838 -6.65804781  2.79544499 -5.3613688   7.7091712   2.64044722
#  -0.91852487  2.20200169  3.25528473  3.8810096   6.85054059 -5.91657761
#   0.81118108  7.30162237]
#
#  Objective function:
#  0.13571388198902354
# <All keys matched successfully>

# %% [markdown]
# ## Probando con los modelos entrenados

# %%
seed = 13
device = 'cpu'
layers = ["GCN", "GAT","GraphConv", "SAGE", "SGConv"]

torch.manual_seed(seed)
Models = [GNN(5, num_classes, name_layer = layer_name) for 
         layer_name in layers]

# %%
# SAGE
vecs = ["GCN_iter_100.txt", "GAT_iter_100.txt", "GraphConv_iter_16.txt", 
        "SAGE_iter_30.txt", "SGConv_iter_39.txt" ]
#for i in range(len(layers)):
for i in range(3,4):
    print(layers[i])
    ps = "./Models/runs/scalefree/Pruebas_GA/TwoLayers/" + vecs[i]

    params = []
    with open(ps) as f:
        for line in f.readlines():
            params.append(float(line.replace("\n","")))
    params = np.array(params) 

    sd = getStateDict(Models[i], params)
    Models[i].load_state_dict(sd)
# Out:
# SAGE

# %%
Models[i].load_state_dict(torch.load("./Models/runs/scalefree/Pruebas_GA/Allfeatures/SAGE_seed_13_thr_5_date_01-14_09-58.pt"))

# %%
Models[i].state_dict()
# Out:
# OrderedDict([('conv1.lin_l.weight',
#               tensor([[ 4.8440,  5.5367,  7.3149,  9.7360,  8.4222],
#                       [-5.7724, -3.0630,  0.7212,  0.0965,  7.7879]])),
#              ('conv1.lin_l.bias', tensor([ 0.2518, -0.2478])),
#              ('conv1.lin_r.weight',
#               tensor([[-8.2475, -3.1878, -8.4482,  3.9230,  5.2051],
#                       [-5.9867,  9.7896,  4.6531,  8.0297,  5.7855]]))])

# %%
"GAT"[:4]
# Out:
# 'GAT'

# %%
torch.save(Models[i].state_dict(), 
           f = f"./Models/runs/scalefree/Pruebas_GA/TwoLayers/SAGE30_seed_13_thr_5_date_01-21_20-53.pt")

# %%
dd = igraph.Graph().Read_Edgelist(file_graph_short).to_networkx()
Features = []
temp = []
try:
    with open(file_short) as f:
        c = 0

        for line in f.readlines()[1:]:
            c+=1
            feats = np.array(line.split(","), dtype = float)
            temp.append(feats)
    temp = np.array(temp)
    
    Features.append(temp)
except Exception as e:
    print(er)
    print(line)
    print(c)
    print(e)

x_p = Convert2DataSet([dd], [[]], feats = Features, scale = True)
torch.exp(Models[i](x_p[0]))
# Out:
# tensor([[1.1799e-02, 9.8820e-01],
#         [4.8888e-03, 9.9511e-01],
#         [1.7897e-02, 9.8210e-01],
#         ...,
#         [8.8733e-01, 1.1267e-01],
#         [9.9955e-01, 4.5231e-04],
#         [9.6518e-01, 3.4815e-02]], grad_fn=<ExpBackward0>)

# %%
x_p[0]
# Out:
# Data(edge_index=[2, 819090], num_nodes=50515, x=[50515, 5], y=[50515], num_classes=2)

# %%
dc = igraph.Graph.Read_Edgelist(file_graph_short, directed = True).to_networkx()
x_p = Convert2DataSet([dc], [[]], feats = Features, scale = True)
#FindMinimumTarget(dc, torch.tensor(torch.exp(Models[i](x_p[0])).detach().numpy().T[1]))
kk = torch.exp(Models[i](x_p[0]))
dc = igraph.Graph.Read_Edgelist(file_graph_short, directed = False).to_networkx()
#_, ts = FindMinimumTarget(dc, torch.tensor(kk.detach().numpy().T[1]))
ts
# Out:
# 2024

# %%
x_p[0]
# Out:
# Data(edge_index=[2, 1638180], num_nodes=50515, x=[50515, 5], y=[50515], num_classes=2)

# %%
dc = igraph.Graph.Read_Edgelist(file_graph_short, directed = False).to_networkx()
x_p = Convert2DataSet([dc], [[]], feats = Features, scale = True)
_, ts = FindMinimumTarget(dc, torch.tensor(torch.exp(Models[i](x_p[0])).detach().numpy().T[1]))
ts
# Out:
# 2024

# %%
x_p = Convert2DataSet([dd], [[]], feats = None, scale = True)
Models[i](x_p[0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_16826/27574511.py in <module>
#       1 x_p = Convert2DataSet([dd], [[]], feats = None, scale = True)
# ----> 2 Models[i](x_p[0])
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_16826/1655516925.py in forward(self, data)
#      53         x, edge_index = data.x, data.edge_index
#      54
# ---> 55         x = self.conv1(x, edge_index)
#      56         x = F.relu(x)
#      57         #x = F.dropout(x, training=self.training)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/torch_geometric/nn/conv/sage_conv.py in forward(self, x, edge_index, size)
#     130         # propagate_type: (x: OptPairTensor)
#     131         out = self.propagate(edge_index, x=x, size=size)
# --> 132         out = self.lin_l(out)
#     133
#     134         x_r = x[1]
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/torch_geometric/nn/dense/linear.py in forward(self, x)
#     134             x (Tensor): The features.
#     135         """
# --> 136         return F.linear(x, self.weight, self.bias)
#     137
#     138     @torch.no_grad()
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (2888x1 and 5x2)

# %%
x_p = Convert2DataSet([G_short], [[]], feats = None, scale = True)[0]
Models[i](x_p[0]);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_16826/2409245279.py in <module>
#       1 x_p = Convert2DataSet([G_short], [[]], feats = None, scale = True)[0]
# ----> 2 Models[i](x_p[0]);
#
# ~/anaconda3/lib/python3.9/site-packages/torch_geometric/data/data.py in __getitem__(self, key)
#     442     # can accept key: Union[str, TensorAttr] in __getitem__.
#     443     def __getitem__(self, key: str) -> Any:
# --> 444         return self._store[key]
#     445
#     446     def __setitem__(self, key: str, value: Any):
#
# ~/anaconda3/lib/python3.9/site-packages/torch_geometric/data/storage.py in __getitem__(self, key)
#      83
#      84     def __getitem__(self, key: str) -> Any:
# ---> 85         return self._mapping[key]
#      86
#      87     def __setitem__(self, key: str, value: Any):
#
# KeyError: 0

# %%
getDataSet(file_short, file_graph_short, scale = SCL, remove_BC=False)[0]

# %%
getDataSet??

# %%
loadGraph??

# %%
#Trials = ["gemsec_facebook_artist", "graph_karate", "socfb-Mich67", "graph_ncstrlwg2", "graph_CA-HepPh", "graph_CA-AstroPh", 
#              "musae_git", "graph_CA-CondMat", "graph_Email-Enron", "gemsec_facebook_artist", "deezer_HR"]

Trials = [k.replace(".txt","") for k in os.listdir("./BRKGA/instances/socialnetworks/txt/") if ".txt" in k]
Trials.sort(reverse=True)

Res = {t:{trial:{} for trial in Trials} for t in layers}
i = 3
print(f"\n---------{layers[i]}---------\n")


for trial in Trials:
    print(f"\nSig: {trial} \n")
    file_short = f"./BRKGA/instances/socialnetworks/feats/{trial}_feat.txt"
    file_graph_short = f"./BRKGA/instances/socialnetworks/txt/{trial}.txt"

    DS_short = getDataSet(file_short, file_graph_short, scale = SCL, remove_BC=True)[0]

    G_short = loadGraph(file_graph_short)

    y_pred = torch.exp(Models[i](DS_short)).T[1]
    
    save("./Models/probabilidades/scalefree_socialnetworks/Pruebas_GA/SinBC/",trial+".txt","SAGE",y_pred)
# Out:
# ---------SAGE---------
#
#
# Sig: socfb-nips-ego
#
#
# Sig: socfb-Mich67
#
#
# Sig: socfb-Brandeis99
#
#
# Sig: soc-gplus
#
#
# Sig: musae_git
#
#
# Sig: loc-gowalla_edges
#
#
# Sig: graph_ncstrlwg2
#
#
# Sig: graph_karate
#
#
# Sig: graph_jazz
#
#
# Sig: graph_football
#
#
# Sig: graph_dolphins
#
#
# Sig: graph_actors_dat
#
#
# Sig: graph_Email-Enron
#
#
# Sig: graph_CA-HepTh
#
#
# Sig: graph_CA-HepPh
#
#
# Sig: graph_CA-GrQc
#
#
# Sig: graph_CA-CondMat
#
#
# Sig: graph_CA-AstroPh
#
#
# Sig: gemsec_facebook_artist
#
#
# Sig: ego-facebook
#
#
# Sig: deezer_HR
#
#
# Sig: com-dblp.ungraph
#
#
# Sig: Amazon0601
#
#
# Sig: Amazon0505
#
#
# Sig: Amazon0312
#
#
# Sig: Amazon0302

# %%
Trials = [k.replace(".txt", "") for k in os.listdir("./BRKGA/instances/Erdos/test/txt/")]
Trials.sort(reverse=True)

Res = {t:{trial:{} for trial in Trials} for t in layers}
i = 3
print(f"\n---------{layers[i]}---------\n")


for trial in Trials:
    print(f"\nSig: {trial} \n")
    file_short = f"./BRKGA/instances/Erdos/test/feats/{trial}_feat.txt"
    file_graph_short = f"./BRKGA/instances/Erdos/test/txt/{trial}.txt"

    DS_short = getDataSet(file_short, file_graph_short, scale = SCL, remove_BC=True)[0]

    G_short = loadGraph(file_graph_short)

    y_pred = torch.exp(Models[i](DS_short)).T[1]
    save("./Models/probabilidades/scalefree_Erdos/Pruebas_GA/SinBC/",trial+".txt","SAGE",y_pred)
# Out:
# ---------SAGE---------
#
#
# Sig: ER_50000_20_0
#
#
# Sig: ER_50000_15_0
#
#
# Sig: ER_50000_10_0
#
#
# Sig: ER_30000_20_0
#
#
# Sig: ER_30000_15_0
#
#
# Sig: ER_30000_10_0
#
#
# Sig: ER_20000_20_1
#
#
# Sig: ER_20000_20_0
#
#
# Sig: ER_20000_15_1
#
#
# Sig: ER_20000_15_0
#
#
# Sig: ER_20000_10_1
#
#
# Sig: ER_20000_10_0
#
#
# Sig: ER_10000_20_1
#
#
# Sig: ER_10000_20_0
#
#
# Sig: ER_10000_15_1
#
#
# Sig: ER_10000_15_0
#
#
# Sig: ER_10000_10_1
#
#
# Sig: ER_10000_10_0

# %%
Models[i]
# Out:
# GNN(
#   (conv1): SAGEConv(5, 2, aggr=mean)
# )

# %%
# Guardando las probs para hacer pruebas
def save(PATH_SAVE_RESULTS, name, model, out):
    with open(f'{PATH_SAVE_RESULTS}{model}_{name}', 'w') as f:
        out = out.detach().numpy()
        e = 0.0001
        for o in out:
            f.write(str(np.round(o + e, 6)))
            f.write("\n")

# %%
Trials = [k.replace(".txt", "") for k in os.listdir("./BRKGA/instances/Erdos/test/txt/")]

Res_er = {t:{trial:{} for trial in Trials} for t in layers}

print(f"\n---------{layers[i]}---------\n")


for trial in Trials:
    print(f"\nSig: {trial} \n")
    file_short = f"./BRKGA/instances/Erdos/test/feats/{trial}_feat.txt"
    file_graph_short = f"./BRKGA/instances/Erdos/test/txt/{trial}.txt"

    DS_short = getDataSet(file_short, file_graph_short, scale = SCL, remove_BC=True)[0]

    G_short = loadGraph(file_graph_short)

    y_pred = torch.exp(Models[i](DS_short)).T[1]
    #plt.hist(y_pred.detach().numpy())

    _, ts = FindMinimumTarget(G_short, out = y_pred, threshold = 0.5, print_= False)
    Res_er[layers[i]][trial]["H"] = ts
    print(ts)

    y_deg = y_pred.detach().numpy() * np.array(list(nx.degree(G_short))).T[1]
    _, ts = FindMinimumTarget(G_short, out = torch.tensor(y_deg) , threshold = 0.5, print_= False)
    Res_er[layers[i]][trial]["HM"] = ts
Res_er
# Out:
# ---------SGConv---------
#
#
# Sig: ER_20000_10_0
#
# 3354
#
# Sig: ER_20000_20_1
#
# 4788
#
# Sig: ER_30000_15_0
#
# 6235
#
# Sig: ER_20000_10_1
#
# 3305
#
# Sig: ER_20000_15_1
#
# 4064
#
# Sig: ER_50000_10_0
#
# 8347
#
# Sig: ER_20000_20_0
#
# 4732
#
# Sig: ER_10000_10_0
#
# 1689
#
# Sig: ER_10000_15_0
#
# 2065
#
# Sig: ER_10000_20_1
#
# 2471
#
# Sig: ER_20000_15_0
#
# 4146
#
# Sig: ER_30000_10_0
#
# 4957
#
# Sig: ER_50000_15_0
#
# 10505
#
# Sig: ER_10000_10_1
#
# 1723
#
# Sig: ER_10000_15_1
#
# 2075
#
# Sig: ER_10000_20_0
#
# 2412
#
# Sig: ER_30000_20_0
#
# 6957
#
# Sig: ER_50000_20_0
#
# 11543
# {'GCN': {'ER_20000_10_0': {},
#   'ER_20000_20_1': {},
#   'ER_30000_15_0': {},
#   'ER_20000_10_1': {},
#   'ER_20000_15_1': {},
#   'ER_50000_10_0': {},
#   'ER_20000_20_0': {},
#   'ER_10000_10_0': {},
#   'ER_10000_15_0': {},
#   'ER_10000_20_1': {},
#   'ER_20000_15_0': {},
#   'ER_30000_10_0': {},
#   'ER_50000_15_0': {},
#   'ER_10000_10_1': {},
#   'ER_10000_15_1': {},
#   'ER_10000_20_0': {},
#   'ER_30000_20_0': {},
#   'ER_50000_20_0': {}},
#  'GAT': {'ER_20000_10_0': {},
#   'ER_20000_20_1': {},
#   'ER_30000_15_0': {},
#   'ER_20000_10_1': {},
#   'ER_20000_15_1': {},
#   'ER_50000_10_0': {},
#   'ER_20000_20_0': {},
#   'ER_10000_10_0': {},
#   'ER_10000_15_0': {},
#   'ER_10000_20_1': {},
#   'ER_20000_15_0': {},
#   'ER_30000_10_0': {},
#   'ER_50000_15_0': {},
#   'ER_10000_10_1': {},
#   'ER_10000_15_1': {},
#   'ER_10000_20_0': {},
#   'ER_30000_20_0': {},
#   'ER_50000_20_0': {}},
#  'GraphConv': {'ER_20000_10_0': {},
#   'ER_20000_20_1': {},
#   'ER_30000_15_0': {},
#   'ER_20000_10_1': {},
#   'ER_20000_15_1': {},
#   'ER_50000_10_0': {},
#   'ER_20000_20_0': {},
#   'ER_10000_10_0': {},
#   'ER_10000_15_0': {},
#   'ER_10000_20_1': {},
#   'ER_20000_15_0': {},
#   'ER_30000_10_0': {},
#   'ER_50000_15_0': {},
#   'ER_10000_10_1': {},
#   'ER_10000_15_1': {},
#   'ER_10000_20_0': {},
#   'ER_30000_20_0': {},
#   'ER_50000_20_0': {}},
#  'SAGE': {'ER_20000_10_0': {},
#   'ER_20000_20_1': {},
#   'ER_30000_15_0': {},
#   'ER_20000_10_1': {},
#   'ER_20000_15_1': {},
#   'ER_50000_10_0': {},
#   'ER_20000_20_0': {},
#   'ER_10000_10_0': {},
#   'ER_10000_15_0': {},
#   'ER_10000_20_1': {},
#   'ER_20000_15_0': {},
#   'ER_30000_10_0': {},
#   'ER_50000_15_0': {},
#   'ER_10000_10_1': {},
#   'ER_10000_15_1': {},
#   'ER_10000_20_0': {},
#   'ER_30000_20_0': {},
#   'ER_50000_20_0': {}},
#  'SGConv': {'ER_20000_10_0': {'H': 3354, 'HM': 3286},
#   'ER_20000_20_1': {'H': 4788, 'HM': 4631},
#   'ER_30000_15_0': {'H': 6235, 'HM': 6035},
#   'ER_20000_10_1': {'H': 3305, 'HM': 3225},
#   'ER_20000_15_1': {'H': 4064, 'HM': 4000},
#   'ER_50000_10_0': {'H': 8347, 'HM': 8144},
#   'ER_20000_20_0': {'H': 4732, 'HM': 4619},
#   'ER_10000_10_0': {'H': 1689, 'HM': 1627},
#   'ER_10000_15_0': {'H': 2065, 'HM': 1999},
#   'ER_10000_20_1': {'H': 2471, 'HM': 2330},
#   'ER_20000_15_0': {'H': 4146, 'HM': 3965},
#   'ER_30000_10_0': {'H': 4957, 'HM': 4889},
#   'ER_50000_15_0': {'H': 10505, 'HM': 10151},
#   'ER_10000_10_1': {'H': 1723, 'HM': 1640},
#   'ER_10000_15_1': {'H': 2075, 'HM': 2025},
#   'ER_10000_20_0': {'H': 2412, 'HM': 2312},
#   'ER_30000_20_0': {'H': 6957, 'HM': 6810},
#   'ER_50000_20_0': {'H': 11543, 'HM': 11288}}}

# %%
# Evaluando sobre varios grafos
Trials = ["graph_karate", "socfb-Mich67", "graph_ncstrlwg2", "graph_CA-HepPh", "graph_CA-AstroPh", 
              "musae_git", "graph_CA-CondMat", "graph_Email-Enron", "gemsec_facebook_artist", "deezer_HR"]

Res = {t:{trial:{} for trial in Trials} for t in layers}

for i in (range(len(layers))):
    print(f"\n---------{layers[i]}---------\n")
    

    for trial in Trials:
        #print(f"\nSig: {trial} \n")
        file_short = f"./BRKGA/instances/socialnetworks/feats/{trial}_feat.txt"
        file_graph_short = f"./BRKGA/instances/socialnetworks/txt/{trial}.txt"

        DS_short = getDataSet(file_short, file_graph_short, scale = SCL)[0]

        G_short = loadGraph(file_graph_short)

        y_pred = torch.exp(Models[i](DS_short)).T[1]
        #plt.hist(y_pred.detach().numpy())

        _, ts = FindMinimumTarget(G_short, out = y_pred, threshold = 0.5, print_= False)
        Res[layers[i]][trial]["H"] = ts

        y_deg = y_pred.detach().numpy() * np.array(list(nx.degree(G_short))).T[1]
        _, ts = FindMinimumTarget(G_short, out = torch.tensor(y_deg) , threshold = 0.5, print_= False)
        Res[layers[i]][trial]["HM"] = ts
Res
# Out:
# ---------GCN---------
# /home/iiia/iiia/GNN-BRKGA/FastCover/utils.py:111: RuntimeWarning: invalid value encountered in true_divide
#   Infected += (Num_Neighs_Infected/Num_Neighs >= threshold)
# ---------GAT---------
#
#
# ---------GraphConv---------
#
#
# ---------SAGE---------
#
#
# ---------SGConv---------
# {'GCN': {'graph_karate': {'H': 10, 'HM': 8},
#   'socfb-Mich67': {'H': 211, 'HM': 203},
#   'graph_ncstrlwg2': {'H': 1131, 'HM': 1120},
#   'graph_CA-HepPh': {'H': 1555, 'HM': 1535},
#   'graph_CA-AstroPh': {'H': 1724, 'HM': 1637},
#   'musae_git': {'H': 235, 'HM': 198},
#   'graph_CA-CondMat': {'H': 2944, 'HM': 2927},
#   'graph_Email-Enron': {'H': 2847, 'HM': 2848},
#   'gemsec_facebook_artist': {'H': 772, 'HM': 802},
#   'deezer_HR': {'H': 2502, 'HM': 2447}},
#  'GAT': {'graph_karate': {'H': 20, 'HM': 13},
#   'socfb-Mich67': {'H': 1337, 'HM': 220},
#   'graph_ncstrlwg2': {'H': 1713, 'HM': 1113},
#   'graph_CA-HepPh': {'H': 4337, 'HM': 1619},
#   'graph_CA-AstroPh': {'H': 7464, 'HM': 1869},
#   'musae_git': {'H': 9733, 'HM': 479},
#   'graph_CA-CondMat': {'H': 6606, 'HM': 2921},
#   'graph_Email-Enron': {'H': 9580, 'HM': 2933},
#   'gemsec_facebook_artist': {'H': 19886, 'HM': 1087},
#   'deezer_HR': {'H': 15446, 'HM': 2647}},
#  'GraphConv': {'graph_karate': {'H': 15, 'HM': 14},
#   'socfb-Mich67': {'H': 988, 'HM': 206},
#   'graph_ncstrlwg2': {'H': 1193, 'HM': 1140},
#   'graph_CA-HepPh': {'H': 2060, 'HM': 1554},
#   'graph_CA-AstroPh': {'H': 3899, 'HM': 1647},
#   'musae_git': {'H': 3085, 'HM': 195},
#   'graph_CA-CondMat': {'H': 3764, 'HM': 2963},
#   'graph_Email-Enron': {'H': 5740, 'HM': 2884},
#   'gemsec_facebook_artist': {'H': 9048, 'HM': 785},
#   'deezer_HR': {'H': 7867, 'HM': 2386}},
#  'SAGE': {'graph_karate': {'H': 9, 'HM': 8},
#   'socfb-Mich67': {'H': 327, 'HM': 299},
#   'graph_ncstrlwg2': {'H': 1110, 'HM': 1098},
#   'graph_CA-HepPh': {'H': 1580, 'HM': 1483},
#   'graph_CA-AstroPh': {'H': 1978, 'HM': 1699},
#   'musae_git': {'H': 2876, 'HM': 230},
#   'graph_CA-CondMat': {'H': 2917, 'HM': 2757},
#   'graph_Email-Enron': {'H': 3333, 'HM': 2828},
#   'gemsec_facebook_artist': {'H': 2024, 'HM': 930},
#   'deezer_HR': {'H': 5066, 'HM': 3029}},
#  'SGConv': {'graph_karate': {'H': 9, 'HM': 8},
#   'socfb-Mich67': {'H': 208, 'HM': 203},
#   'graph_ncstrlwg2': {'H': 1135, 'HM': 1114},
#   'graph_CA-HepPh': {'H': 1554, 'HM': 1541},
#   'graph_CA-AstroPh': {'H': 1705, 'HM': 1635},
#   'musae_git': {'H': 235, 'HM': 198},
#   'graph_CA-CondMat': {'H': 2946, 'HM': 2932},
#   'graph_Email-Enron': {'H': 2851, 'HM': 2876},
#   'gemsec_facebook_artist': {'H': 778, 'HM': 786},
#   'deezer_HR': {'H': 2477, 'HM': 2438}}}

# %%
Trials = ["graph_karate", "socfb-Mich67", "graph_ncstrlwg2", "graph_CA-HepPh", "graph_CA-AstroPh", 
              "musae_git", "graph_CA-CondMat", "graph_Email-Enron", "gemsec_facebook_artist", "deezer_HR"]

Res_MDH = {t:{trial:{} for trial in Trials} for t in ["MDH"]}
for trial in Trials:
        #print(f"\nSig: {trial} \n")
        file_short = f"./BRKGA/instances/socialnetworks/feats/{trial}_feat.txt"
        file_graph_short = f"./BRKGA/instances/socialnetworks/txt/{trial}.txt"

        #DS_short = getDataSet(file_short, file_graph_short, scale = SCL)[0]

        G_short = loadGraph(file_graph_short)

        _, ts = FindMinimumTarget(G_short, out = None, threshold = 0.5, print_= False)
        
        Res_MDH["MDH"][trial]["H"] = ts
Res_MDH
# Out:
# {'MDH': {'graph_karate': {'H': 8},
#   'socfb-Mich67': {'H': 206},
#   'graph_ncstrlwg2': {'H': 1108},
#   'graph_CA-HepPh': {'H': 1525},
#   'graph_CA-AstroPh': {'H': 1637},
#   'musae_git': {'H': 196},
#   'graph_CA-CondMat': {'H': 2936},
#   'graph_Email-Enron': {'H': 2880},
#   'gemsec_facebook_artist': {'H': 789},
#   'deezer_HR': {'H': 2377}}}

# %%
Trials = [k.replace(".txt", "") for k in os.listdir("./BRKGA/instances/Erdos/test/txt/")]

Res_er = {t:{trial:{} for trial in Trials} for t in layers}

for i in (range(len(layers))):
    print(f"\n---------{layers[i]}---------\n")
    

    for trial in Trials:
        #print(f"\nSig: {trial} \n")
        file_short = f"./BRKGA/instances/Erdos/test/feats/{trial}_feat.txt"
        file_graph_short = f"./BRKGA/instances/Erdos/test/txt/{trial}.txt"

        DS_short = getDataSet(file_short, file_graph_short, scale = SCL)[0]

        G_short = loadGraph(file_graph_short)

        y_pred = torch.exp(Models[i](DS_short)).T[1]
        #plt.hist(y_pred.detach().numpy())

        _, ts = FindMinimumTarget(G_short, out = y_pred, threshold = 0.5, print_= False)
        Res_er[layers[i]][trial]["H"] = ts

        y_deg = y_pred.detach().numpy() * np.array(list(nx.degree(G_short))).T[1]
        _, ts = FindMinimumTarget(G_short, out = torch.tensor(y_deg) , threshold = 0.5, print_= False)
        Res_er[layers[i]][trial]["HM"] = ts
Res_er
# Out:
# ---------GCN---------
#
#
# ---------GAT---------
#
#
# ---------GraphConv---------
#
#
# ---------SAGE---------
#
#
# ---------SGConv---------
# {'GCN': {'ER_20000_10_0': {'H': 3368, 'HM': 3317},
#   'ER_20000_20_1': {'H': 4817, 'HM': 4615},
#   'ER_30000_15_0': {'H': 6274, 'HM': 6047},
#   'ER_20000_10_1': {'H': 3323, 'HM': 3239},
#   'ER_20000_15_1': {'H': 4119, 'HM': 4020},
#   'ER_50000_10_0': {'H': 8416, 'HM': 8207},
#   'ER_20000_20_0': {'H': 4764, 'HM': 4621},
#   'ER_10000_10_0': {'H': 1675, 'HM': 1637},
#   'ER_10000_15_0': {'H': 2076, 'HM': 2005},
#   'ER_10000_20_1': {'H': 2474, 'HM': 2296},
#   'ER_20000_15_0': {'H': 4187, 'HM': 3996},
#   'ER_30000_10_0': {'H': 5020, 'HM': 4930},
#   'ER_50000_15_0': {'H': 10555, 'HM': 10106},
#   'ER_10000_10_1': {'H': 1704, 'HM': 1640},
#   'ER_10000_20_1': {'H': 2205, 'HM': 2212},
#   'ER_20000_15_0': {'H': 3882, 'HM': 3877},
#   'ER_30000_10_0': {'H': 4668, 'HM': 4668},
#   'ER_50000_15_0': {'H': 9593, 'HM': 9623},
#   'ER_10000_10_1': {'H': 1566, 'HM': 1568},
#   'ER_10000_15_1': {'H': 1945, 'HM': 1932},
#   'ER_10000_20_0': {'H': 2186, 'HM': 2205},
#   'ER_30000_20_0': {'H': 6609, 'HM': 6606},
#   'ER_50000_20_0': {'H': 10884, 'HM': 10883}},
#  'SGConv': {'ER_20000_10_0': {'H': 3373, 'HM': 3307},
#   'ER_20000_20_1': {'H': 4824, 'HM': 4575},
#   'ER_30000_15_0': {'H': 6286, 'HM': 6031},
#   'ER_20000_10_1': {'H': 3329, 'HM': 3239},
#   'ER_20000_15_1': {'H': 4131, 'HM': 4013},
#   'ER_50000_10_0': {'H': 8427, 'HM': 8193},
#   'ER_20000_20_0': {'H': 4762, 'HM': 4597},
#   'ER_10000_10_0': {'H': 1677, 'HM': 1620},
#   'ER_10000_15_0': {'H': 2082, 'HM': 2008},
#   'ER_10000_20_1': {'H': 2466, 'HM': 2287},
#   'ER_20000_15_0': {'H': 4190, 'HM': 3993},
#   'ER_30000_10_0': {'H': 5030, 'HM': 4932},
#   'ER_50000_15_0': {'H': 10564, 'HM': 10085},
#   'ER_10000_10_1': {'H': 1698, 'HM': 1636},
#   'ER_10000_15_1': {'H': 2080, 'HM': 2001},
#   'ER_10000_20_0': {'H': 2423, 'HM': 2295},
#   'ER_30000_20_0': {'H': 7023, 'HM': 6823},
#   'ER_50000_20_0': {'H': 11688, 'HM': 11325}}}

# %%
Trials = [k.replace(".txt", "") for k in os.listdir("./BRKGA/instances/Erdos/test/txt/")]
Res_MDH_er = {t:{trial:{} for trial in Trials} for t in ["MDH"]}

for trial in Trials:
        #print(f"\nSig: {trial} \n")
        file_short = f"./BRKGA/instances/Erdos/test/feats/{trial}_feat.txt"
        file_graph_short = f"./BRKGA/instances/Erdos/test/txt/{trial}.txt"

        #DS_short = getDataSet(file_short, file_graph_short, scale = SCL)[0]

        G_short = loadGraph(file_graph_short)

        _, ts = FindMinimumTarget(G_short, out = None, threshold = 0.5, print_= False)
        
        Res_MDH_er["MDH"][trial]["H"] = ts
Res_MDH_er
# Out:
# {'MDH': {'ER_20000_10_0': {'H': 3228},
#   'ER_20000_20_1': {'H': 4512},
#   'ER_30000_15_0': {'H': 5923},
#   'ER_20000_10_1': {'H': 3187},
#   'ER_20000_15_1': {'H': 3964},
#   'ER_50000_10_0': {'H': 8055},
#   'ER_20000_20_0': {'H': 4529},
#   'ER_10000_10_0': {'H': 1625},
#   'ER_10000_15_0': {'H': 1966},
#   'ER_10000_20_1': {'H': 2255},
#   'ER_20000_15_0': {'H': 3942},
#   'ER_30000_10_0': {'H': 4852},
#   'ER_50000_15_0': {'H': 9898},
#   'ER_10000_10_1': {'H': 1624},
#   'ER_10000_15_1': {'H': 1974},
#   'ER_10000_20_0': {'H': 2249},
#   'ER_30000_20_0': {'H': 6746},
#   'ER_50000_20_0': {'H': 11188}}}

# %%
Data = pd.DataFrame()
for l in layers:
    d = pd.DataFrame(Res[l]).T
    d.columns = [l+"H", l+"HM"]
    Data = pd.concat([Data, d], axis = 1)

d = pd.DataFrame(Res_MDH["MDH"]).T
d.columns = ["MDH"]
Data = pd.concat([Data, d], axis = 1)
Data.to_csv("ComparacionRapida_sf.csv")

# %%
Data = pd.DataFrame()
for l in layers:
    d = pd.DataFrame(Res_er[l]).T
    d.columns = [l+"H", l+"HM"]
    Data = pd.concat([Data, d], axis = 1)

d = pd.DataFrame(Res_MDH_er["MDH"]).T
d.columns = ["MDH"]
Data = pd.concat([Data, d], axis = 1)
Data.to_csv("ComparacionRapida.csv")

# %%
for ig, data in enumerate(Graphs_Train):
    
        data = data.to(device)
        y_pred = torch.exp(Models[i](data)).T[1]
        ts = len(FindMinimumTarget(graphs[ig], out = y_pred, threshold = 0.5)[0])
        break

# %%
ts
# Out:
# 171

# %%
len(Solutions[0])
# Out:
# 141

# %%
zeros = np.zeros(data.num_nodes)
zeros[torch.topk(y_pred, ts)[1]] = 1
SimpleweightedCrossEntropy(zeros, y_pred.detach().numpy(), [9.2, 1])
# Out:
# 0.35522462109476327

# %%
np.sum(zeros==0)/np.sum(zeros)
# Out:
# 4.847953216374269

# %%
plt.hist(y_pred.detach().numpy())
# Out:
# (array([276., 110.,  69.,  64.,  63.,  46.,  77.,  60.,  96., 139.]),
#  array([0.00273462, 0.10244006, 0.2021455 , 0.30185094, 0.4015564 ,
#         0.50126183, 0.6009673 , 0.70067275, 0.80037814, 0.9000836 ,
#         0.99978906], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
print("Short")
file_short = "./BRKGA/instances/socialnetworks/feats/graph_CA-AstroPh_feat.txt"
file_graph_short = "./BRKGA/instances/socialnetworks/txt/graph_CA-AstroPh.txt"

DS_short = getDataSet(file_short, file_graph_short, scale = SCL)[0]

G_short = loadGraph(file_graph_short)
# Out:
# Short

# %%
y_pred = torch.exp(Models[i](DS_short)).T[1]
plt.hist(y_pred.detach().numpy())
# Out:
# (array([15500.,   585.,   298.,   249.,   207.,   183.,   178.,   216.,
#           238.,  1118.]),
#  array([5.7953154e-04, 1.0052158e-01, 2.0046362e-01, 3.0040568e-01,
#         4.0034771e-01, 5.0028974e-01, 6.0023183e-01, 7.0017385e-01,
#         8.0011588e-01, 9.0005797e-01, 1.0000000e+00], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
_, ts = FindMinimumTarget(G_short, out = None, threshold = 0.5, print_= True,)
ts
# Out:
# FastCover\utils.py:111: RuntimeWarning: invalid value encountered in true_divide
#   Infected += (Num_Neighs_Infected/Num_Neighs >= threshold)
# 0.00 Infected
# 1.00 Infected
# 1637

# %%
_, ts = FindMinimumTarget(G_short, out = y_pred, threshold = 0.5, print_= True,)
ts
# Out:
# /home/iiia/iiia/GNN-BRKGA/FastCover/utils.py:111: RuntimeWarning: invalid value encountered in true_divide
#   Infected += (Num_Neighs_Infected/Num_Neighs >= threshold)
# 0.00 Infected
# 1.00 Infected
# 1705

# %%
y_deg = y_pred.detach().numpy() * np.array(list(nx.degree(G_short))).T[1]
_, ts = FindMinimumTarget(G_short, out = torch.tensor(y_deg) , threshold = 0.5, print_= True,)
ts
# Out:
# 0.00 Infected
# 0.82 Infected
# 0.89 Infected
# 1.00 Infected
# 1635

# %%
print("Large")
file_large = "./BRKGA/instances/socialnetworks/feats/graph_Email-Enron_feat.txt"
file_graph_large = "./BRKGA/instances/socialnetworks/txt/graph_Email-Enron.txt"
DS_large = getDataSet(file_large, file_graph_large, scale=SCL)[0]
G_large = loadGraph(file_graph_large)
# Out:
# Large

# %%
y_pred = torch.exp(Models[i](DS_large)).T[1]
plt.hist(y_pred.detach().numpy())
# Out:
# (array([34995.,   253.,   127.,   114.,    75.,    70.,    69.,    73.,
#           100.,   816.]),
#  array([5.7940639e-04, 1.0052147e-01, 2.0046352e-01, 3.0040559e-01,
#         4.0034765e-01, 5.0028968e-01, 6.0023177e-01, 7.0017380e-01,
#         8.0011588e-01, 9.0005791e-01, 1.0000000e+00], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
#_, ts = FindMinimumTarget(G_large, out = None, threshold = 0.5, print_= True)
ts
# Out:
# 0.03 Infected
# 1.00 Infected
# 2880

# %%
_, ts = FindMinimumTarget(G_large, out = y_pred, threshold = 0.5, print_= True)
ts
# Out:
# 0.00 Infected
# 0.96 Infected
# 1.00 Infected
# 2851

# %%
y_deg = y_pred.detach().numpy() * np.array(list(nx.degree(G_large))).T[1]
_, ts = FindMinimumTarget(G_large, out = torch.tensor(y_deg) , threshold = 0.5, print_= True,)
ts
#2824
# Out:
# 0.03 Infected
# 1.00 Infected
# 2876

# %%
print("Erdos")
file_erdos = "./BRKGA/instances/Erdos/test/feats/ER_30000_15_0_feat.txt"
file_graph_erdos = "./BRKGA/instances/Erdos/test/txt/ER_30000_15_0.txt"
DS_Erdos = getDataSet(file_erdos, file_graph_erdos, scale=SCL)[0]
G_Erdos = loadGraph(file_graph_erdos)
# Out:
# Erdos

# %%
y_pred = torch.exp(Models[i](DS_Erdos)).T[1]
plt.hist(y_pred.detach().numpy())
# Out:
# (array([  729.,   632.,   659.,   687.,   860.,   981.,  1291.,  1889.,
#          3364., 18908.]),
#  array([0.00300855, 0.10270652, 0.20240448, 0.30210245, 0.40180042,
#         0.5014984 , 0.60119635, 0.7008943 , 0.80059224, 0.90029025,
#         0.9999882 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
_, ts = FindMinimumTarget(G_Erdos, out = None, threshold = 0.5, print_= True)
ts
# Out:
# 0.00 Infected
# 0.05 Infected
# 0.10 Infected
# 0.17 Infected
# 1.00 Infected
# 5923

# %%
_, ts = FindMinimumTarget(G_Erdos, out = y_pred, threshold = 0.5, print_= True)
ts
# Out:
# 0.00 Infected
# 0.05 Infected
# 0.10 Infected
# 0.16 Infected
# 0.26 Infected
# 1.00 Infected
# 6286

# %%
y_deg = y_pred.detach().numpy() * np.array(list(nx.degree(G_Erdos))).T[1]
_, ts = FindMinimumTarget(G_Erdos, out = torch.tensor(y_deg) , threshold = 0.5, print_= True,)
ts
#6726
# Out:
# 0.00 Infected
# 0.05 Infected
# 0.10 Infected
# 0.17 Infected
# 0.29 Infected
# 1.00 Infected
# 6031

# %% [markdown]
# ## Recreando el entrenamiento con SAGE

# %%
PATH_TO_TRAIN = "./BRKGA/instances/scalefree/train/"

# %%
Instances = [graph for graph in os.listdir(PATH_TO_TRAIN + 'txt')]
Instances.sort()

graphs = []
for er in Instances:
    graph = igraph.Graph.Read_Edgelist(PATH_TO_TRAIN+"txt/"+er, directed = False)
    graphs.append(graph.to_networkx())    

OptInstances = [graph for graph in os.listdir(PATH_TO_TRAIN+'optimal')]
OptInstances.sort()

Solutions = []
for er in OptInstances:
    opt = []
    with open(PATH_TO_TRAIN+'optimal/'+er) as f:
        for line in f.readlines():
            opt.append(int(line.replace("\n", "")))
    Solutions.append(opt)   


print("\nCargando Features...\n")
graphFeatures = [feat for feat in os.listdir(PATH_TO_TRAIN+'feats')]
graphFeatures.sort()

Features = []
for er in graphFeatures:
    temp = []
    try:
        with open(PATH_TO_TRAIN+'feats/'+er) as f:
            c = 0

            for line in f.readlines()[1:]:
                c+=1
                feats = np.array(line.split(","), dtype = float)
                temp.append(feats)
        temp = np.array(temp)
        #temp = np.delete(temp, 0, 1)
        Features.append(temp)
    except:
        print(er)
        print(line)
        print(c)
    
Graphs_Train = Convert2DataSet(graphs, Solutions, feats = Features)

num_features = Graphs_Train[0].num_features
num_classes = Graphs_Train[0].num_classes


# ======================== ERDOS =================
PATH_TO_TRAIN_er = "./BRKGA/instances/Erdos/train/"
Instances_er = [graph for graph in os.listdir(PATH_TO_TRAIN_er + 'txt')]
Instances_er.sort()

graphs_er = []
for er in Instances_er:
    graph = igraph.Graph.Read_Edgelist(PATH_TO_TRAIN_er+"txt/"+er, directed = False)
    graphs_er.append(graph.to_networkx())    

OptInstances_er = [graph for graph in os.listdir(PATH_TO_TRAIN_er+'optimal')]
OptInstances_er.sort()

Solutions_er = []

for er in OptInstances_er:
    opt = []
    with open(PATH_TO_TRAIN_er+'optimal/'+er) as f:
        for line in f.readlines():
            opt.append(int(line.replace("\n", "")))
    Solutions_er.append(opt)   


print("\nCargando Features...\n")
graphFeatures_er = [feat for feat in os.listdir(PATH_TO_TRAIN_er+'feats')]
graphFeatures_er.sort()

Features_er = []
for er in graphFeatures_er:
    temp = []
    try:
        with open(PATH_TO_TRAIN_er+'feats/'+er) as f:
            c = 0

            for line in f.readlines()[1:]:
                c+=1
                feats = np.array(line.split(","), dtype = float)
                temp.append(feats)
        temp = np.array(temp)
        #temp = np.delete(temp, 0, 1)
        Features_er.append(temp)
    except:
        print(er)
        print(line)
        print(c)
    
Graphs_Train_Erdos = Convert2DataSet(graphs_er, Solutions_er, feats = Features_er)


# ========================

layers = ["SAGE", "GCN", "SGConv", "GAT","GraphConv"]
# Out:
# Cargando Features...
#
#
# Cargando Features...

# %%
torch.manual_seed(13)
Models = [GNN(num_features, num_classes, name_layer = layer_name) for 
         layer_name in layers]

# %%
Models[0]
# Out:
# GNN(
#   (conv1): SAGEConv(5, 2, aggr=mean)
# )

# %%
def Func2(X, MDH = False, alpha = 0.7, scalefree = True):
    # Objective function
    
    if not MDH:
        sd = getStateDict(Models[i], X)
        Models[i].load_state_dict(sd)
    else:
        alpha = 1
        
    value = 0.0
    loss = 0.0
    
    #if scalefree:
    #    Graphs_Train = Graphs_Train_Erdos
    
    
    for ig, data in enumerate(Graphs_Train_Erdos):
        
        if MDH:
            y_pred = None
        else:
            data = data.to(device)
            y_pred = torch.exp(Models[i](data)).T[1]
        
        
        ts = len(FindMinimumTarget(graphs_er[ig], out = y_pred, threshold = 0.5)[0])
        
        val = ts / graphs_er[ig].number_of_nodes()
        
        value += val
        
        #"""
        if not MDH:
            zeros = np.zeros(data.num_nodes)
            zeros[torch.topk(y_pred, ts)[1]] = 1
            weigth_minoritaria = np.sum(zeros==0)/np.sum(zeros)
            loss += SimpleweightedCrossEntropy(zeros, y_pred.detach().numpy(), [weigth_minoritaria, 1])
        
        #"""
        
        
    
    value /= len(Graphs_Train_Erdos) 
    loss /= len(Graphs_Train_Erdos) 
    #return value
    
    return value * (alpha) + loss * (1 - alpha)


def Func(X, MDH = False, alpha = 0.7):
    # Objective function
    
    if not MDH:
        sd = getStateDict(Models[i], X)
        Models[i].load_state_dict(sd)
    else:
        alpha = 1
        
    value = 0.0
    loss = 0.0
    
    for ig, data in enumerate(Graphs_Train):
        
        if MDH:
            y_pred = None
        else:
            data = data.to(device)
            y_pred = torch.exp(Models[i](data)).T[1]
        
        
        ts = len(FindMinimumTarget(graphs[ig], out = y_pred, threshold = 0.5)[0])
        
        val = ts / graphs[ig].number_of_nodes()
        
        value += val
        
        #"""
        if not MDH:
            zeros = np.zeros(data.num_nodes)
            zeros[torch.topk(y_pred, ts)[1]] = 1
            weigth_minoritaria = np.sum(zeros==0)/np.sum(zeros)
            loss += SimpleweightedCrossEntropy(zeros, y_pred.detach().numpy(), [weigth_minoritaria, 1])
        
        #"""
        
        
    
    value /= len(Graphs_Train) 
    loss /= len(Graphs_Train) 
    #return value
    
    return value * (alpha) + loss * (1 - alpha)

# %%
vecs = [k for k in os.listdir("./Models/runs/scalefree/Pruebas_GA/Allfeatures/") if ".txt" in k and "SAGE" in k]

# %%
vecs;

# %%
i = 0
#print(layers[i])
values_sf = []
values_erdos = []

for jj in progressbar.progressbar(range(1, 101)):
    ps = f"./Models/runs/scalefree/Pruebas_GA/Allfeatures/SAGE_iter_{jj}.txt" 

    params = []
    with open(ps) as f:
        for line in f.readlines():
            params.append(float(line.replace("\n","")))
    params = np.array(params) 

    values_sf.append(Func2(params))
    values_erdos.append(Func(params))
# Out:
#   0% (0 of 100) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--FastCover\utils.py:111: RuntimeWarning: invalid value encountered in true_divide
#   Infected += (Num_Neighs_Infected/Num_Neighs >= threshold)
#   6% (6 of 100) |#                       | Elapsed Time: 0:00:56 ETA:   0:15:51

# %%
device = 'cpu'
import progressbar

# %%
plt.plot(values_sf)
plt.plot(values_erdos)
